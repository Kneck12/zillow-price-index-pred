# %% [markdown]
# # 3. Lasso Auto + All Features

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import Lasso
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df_orig = pd.read_csv('../../../full_dataset_unscaled.csv')
df_orig = df_orig.rename(columns={"datetime":"year-month"})
df_orig['net_job_rate']=df_orig['job_creation_rate']-df_orig['job_destruction_rate']
df_orig['apartment_for_rent_searches'] = df_orig[['apartment for rent','studio for rent','1 bedroom for rent','3 bedroom for rent']].sum(axis=1)
df_orig['multifamily_for_rent_searches'] = df_orig[['townhomes for rent','townhouse for rent','house for rent','duplex apartments for rent','condos for rent']].sum(axis=1)
df_orig['gun_searches'] = df_orig[['gun range', 'gun control', 'gun violence']].sum(axis=1)
df_orig['zri'] = np.log(df_orig['zri'])

# %%
gen_cols = ['zip',
 'City',
 'State',
 'Metro',
 'CountyName',
 'zri',
 'year',
 'month',
 'year-month']
acs_cols = ['percent_white',
 'percent_black',
 'percent_asian',
 'percent_hispanic',
 'percent_native_am',
 'percent_other_race',
 'percent_0_17',
 'percent_18_39',
 'percent_40_64',
 'percent_65+',
 'percent_rental_units_vacant',
 'percent_rental_units_occupied',
 'percent_graduate_deg',
 'percent_bachelors',
 'percent_associates',
 'percent_highschool',
 'percent_less_highschool',
 'percent_commute_public_transport',
 'percent_commute_less_30',
 'percent_buildings_less_10_units',
 'percent_buildings_10_19_units',
 'percent_buildings_20_49_units',
 'percent_buildings_50+_units',
 'percent_commute_30_to_59',
 'percent_commute_60_to_89',
 'percent_commute_90_more',
 'percent_new_city',
 'percent_new_unit',
 'percent_units_owner_occupied',
 'median_building_age',
 'income_per_capita',
 'poverty_rate',
 'total_pop',
 'percent_workforce_unemployed',
 'percent_work_from_home',
 'median_age',
 'percent_female',
 'gini_index',
 'percent_not_us_citizen']
acs_cols_remove=['percent_other_race','percent_40_64','percent_0_17','percent_18_39',
       'percent_65+','percent_rental_units_vacant','percent_not_us_citizen','percent_less_highschool', 'percent_buildings_less_10_units',
 'percent_commute_30_to_59',
 'percent_commute_60_to_89',
 'percent_commute_90_more', 'percent_commute_less_30','percent_graduate_deg',
                'percent_female','gini_index','percent_hispanic','percent_black','percent_bachelors',
                 'percent_asian','percent_new_city','percent_new_unit']
acs_cols_keep=list(set(acs_cols) - set(acs_cols_remove))
bikeshare_cols = ['bs_total_stations',
 'bs_total_systems',
 'has_bike_sharing']
bikeshare_cols_remove=['has_bike_sharing','bs_total_systems']
bikeshare_cols_keep=list(set(bikeshare_cols) - set(bikeshare_cols_remove))
trends_cols = ['gun range',
 'gun control',
 'gun violence',
 'job opportunities',
 'unemployment',
 'retirement',
 'layoff',
 'lgbt',
 'same sex marriage',
 'they',
 'pronouns',
 'black lives matter',
 'political correctness',
 'make america great again',
 'euthanasia',
 'getaway',
 'places to go',
 'flight tickets',
 'twitter',
 'hashtag',
 'fake news',
 'hurricane',
 'wildfire',
 'flood',
 'fire',
 "trader joe's",
 'whole foods',
 'lululemon',
 'thrift',
 'condos for rent',
 'duplex apartments for rent',
 'townhomes for rent',
 'townhouses for rent',
 'home for rent',
 'house for rent',
 'townhome for rent',
 'townhouse for rent',
 'apartment for rent',
 'studio for rent',
 '1 bedroom for rent',
 '3 bedroom for rent',
 'starbucks',
  'apartment_for_rent_searches',
  'multifamily_for_rent_searches',
  'gun_searches']
trends_cols_remove=['they','apartment for rent','studio for rent','1 bedroom for rent',
                    '3 bedroom for rent', 'townhome for rent','townhouse for rent','townhomes for rent',
                    'townhouses for rent','house for rent','home for rent','duplex apartments for rent','condos for rent',
                   'gun range', 'gun control', 'gun violence','homes for rent']
trends_cols_keep=list(set(trends_cols) - set(trends_cols_remove))
economic_cols = ['total_firms',
 'job_creation_rate',
 'job_destruction_rate',
 'startup_firms','state_local_perc', 'net_job_rate']
economic_cols_remove=['total_firms', 'job_creation_rate','job_destruction_rate',]
economic_cols_keep=list(set(economic_cols) - set(economic_cols_remove))

# %%
for zipcode in df_orig['zip'].unique():
    globals()[f"scaler_{zipcode}"]=StandardScaler(copy=False)
    df_filtered=df_orig[df_orig['zip']==zipcode]
    df_filtered_train = df_filtered[df_filtered['year']<2019]
    globals()[f"scaler_{zipcode}"].fit(df_filtered_train[['zri']])
    df_orig.loc[df_orig['zip']==zipcode,'zri']=globals()[f"scaler_{zipcode}"].transform(df_filtered[['zri']])

# %%
df_orig = df_orig[gen_cols + acs_cols_keep + bikeshare_cols_keep + economic_cols_keep + trends_cols_keep]

# %%
scale_columns = ['percent_buildings_50+_units', 'percent_associates',
       'percent_rental_units_occupied', 'percent_white', 'percent_highschool',
       'percent_work_from_home', 'percent_buildings_20_49_units',
       'median_building_age', 'median_age', 'percent_commute_public_transport',
       'percent_buildings_10_19_units', 'income_per_capita',
       'percent_native_am', 'percent_workforce_unemployed', 'poverty_rate',
       'percent_units_owner_occupied', 'total_pop', 'bs_total_stations',
       'startup_firms', 'state_local_perc', 'net_job_rate', 'gun_searches',
       'wildfire', 'fire', 'lgbt', 'political correctness', 'lululemon',
       'make america great again', 'same sex marriage', 'job opportunities',
       'retirement', 'black lives matter', 'flight tickets', 'pronouns',
       'trader joe\'s', 'fake news', 'hurricane', 'flood', 'whole foods',
       'twitter', 'thrift', 'hashtag', 'apartment_for_rent_searches', 'layoff',
       'starbucks', 'getaway', 'places to go', 'unemployment', 'euthanasia',
       'multifamily_for_rent_searches']

# %%
for zipcode in df_orig['zip'].unique():
    globals()[f"scaler_features_{zipcode}"]=StandardScaler(copy=False)
    df_filtered=df_orig[df_orig['zip']==zipcode]
    df_filtered_train = df_filtered[df_filtered['year']<2019]
    globals()[f"scaler_features_{zipcode}"].fit(df_filtered_train[scale_columns])
    df_orig.loc[df_orig['zip']==zipcode,scale_columns]=globals()[f"scaler_features_{zipcode}"].transform(df_filtered[scale_columns])

# %%
df_zri_all = df_orig

# %%
def laggenerator(i,colname,df):
    timelist=list(df['year-month'].drop_duplicates().sort_values())[0:i]
    df.loc[:,f'{colname}_lag{i}']=df.loc[:,f'{colname}'].shift(i)
    df.loc[df['year-month'].isin(timelist),f'{colname}_lag{i}']=0
    return df

def laggenerator_diff(i,colname,df):
    timelist=list(df['year-month'].drop_duplicates().sort_values())[0:i+1]
    df.loc[:,f'{colname}_diff_lag{i}_lag{i+1}']=df.loc[:,f'{colname}'].shift(i)-df.loc[:,f'{colname}'].shift(i+1)
    df.loc[df['year-month'].isin(timelist),f'{colname}_diff_lag{i}_lag{i+1}']=0
    return df

def laggenerator_diff12(i,colname,df):
    timelist=list(df['year-month'].drop_duplicates().sort_values())[0:i+11]
    df.loc[:,f'{colname}_diff_lag{i}_lag{i+11}']=df.loc[:,f'{colname}'].shift(i)-df.loc[:,f'{colname}'].shift(i+11)
    df.loc[df['year-month'].isin(timelist),f'{colname}_diff_lag{i}_lag{i+11}']=0
    return df

#ZRI 
def lag_gen(df):
    for i in range(1,12):
        df=laggenerator(i, 'zri', df)
    df=laggenerator_diff12(1, 'zri', df)
    return df

# %%
#ZRI
df_zri_all = lag_gen(df_zri_all)

#ACS
for col in acs_cols_keep:
    df_zri_all = laggenerator_diff12(1,col,df_zri_all)
    df_zri_all = laggenerator(1,col,df_zri_all)
    df_zri_all = laggenerator(6,col,df_zri_all)
    df_zri_all = laggenerator(12,col,df_zri_all)
    
#BIKESHARE AND ECONOMIC 
for col in bikeshare_cols_keep + economic_cols_keep:
    df_zri_all = laggenerator(1, col, df_zri_all)
    df_zri_all = laggenerator_diff12(1, col, df_zri_all)  
    
#TRENDS 
for col in trends_cols_keep:
    for i in range(1,4):
        df_zri_all=laggenerator(i, col, df_zri_all)

# %%
df = df_zri_all[df_zri_all['year-month']>='2015-04-01']
train = df[(df['year'] < 2019) & (df['year']>=2015)]
test = df[df['year']==2019]

train = train.sort_values(by='year-month',ascending=True)
test = test.sort_values(by='year-month',ascending=True)

save_train = train.copy()
save_test = test.copy()

# %%
train = train.drop(['zip','City','State','Metro','CountyName','year','month','year-month'],axis=1)
train_y = train['zri']
train_X = train.drop(['zri'],axis=1)

test_y = test['zri']
test_X = test

# %%
#Lasso Grid Search
fold=TimeSeriesSplit(n_splits=5)
lasso = Lasso()
grid = dict()
grid['alpha'] = [0.001,0.01,0.05,0.1,0.5,1,10]
lasso_grid = GridSearchCV(lasso, grid, cv=fold, n_jobs=-1).fit(train_X,train_y)
#lasso_best = lasso_grid.best_estimator_

# %%
lasso_best = Lasso(alpha=0.01)

# %%
lasso_best.fit(train_X, train_y)
# Out:
# Lasso(alpha=0.01)

# %%
predictor_table=df.copy()
X_test = test_X.copy()

#loop through all month in 2019
for month in list(X_test['year-month'].drop_duplicates()):
    
    #run prediction for one month
    X_test=X_test[X_test['year-month']==month]
    X_test=X_test.drop(['zip','year','month','City','State','Metro','CountyName','year-month','zri'],axis=1)
    val=lasso_best.predict(X_test)

    #write current month prediction into predictor_table

    predictor_table.loc[predictor_table['year-month']==month,'zri']=val
        
    predictor_table=lag_gen(predictor_table)

    X_test=predictor_table[predictor_table['year']==2019]

scaled_predictions_y = X_test['zri']
temp = pd.concat([save_test['zip'],test_y],axis=1)
temp.reset_index(drop=True, inplace=True)
scaled_predictions_y.reset_index(drop=True, inplace=True)
rstable = pd.concat([temp,scaled_predictions_y],axis=1)
rstable.columns = ['zip','zri_test','zri_predicted']

for zipcode in rstable['zip'].unique():
    rstable_filtered=rstable[rstable['zip']==zipcode]
    rstable.loc[rstable['zip']==zipcode,'zri_test']=globals()[f"scaler_{zipcode}"].inverse_transform(rstable_filtered[['zri_test']])
    rstable.loc[rstable['zip']==zipcode,'zri_predicted']=globals()[f"scaler_{zipcode}"].inverse_transform(rstable_filtered[['zri_predicted']])  
rstable.loc[:,'zri_test'] = np.exp(rstable.loc[:,'zri_test'])
rstable.loc[:,'zri_predicted'] = np.exp(rstable.loc[:,'zri_predicted'])
rstable
# Out:
#          zip  zri_test  zri_predicted
# 0       1013    1099.0    1104.739851
# 1      14850    1545.0    1597.069313
# 2       6114    1139.0    1092.595199
# 3      90804    1957.0    1808.995912
# 4      59601     845.4     843.381935
# ...      ...       ...            ...
# 15607  14217     901.0     923.533427
# 15608  60611    2138.0    2240.269399
# 15609  93307     883.0     899.062315
# 15610  10019    3619.0    3745.236626
# 15611  99654    1224.0    1345.270713
#
# [15612 rows x 3 columns]

# %%
#RESULTS 
r2 = r2_score(rstable['zri_test'],rstable['zri_predicted'])
rmse = sqrt(mean_squared_error(rstable['zri_test'],rstable['zri_predicted']))
print(f'R2: {r2*100}')
print(f'RMSE: {rmse}')
# Out:
# R2: 96.78959391649265
# RMSE: 119.20767979158444

# %%
importance = np.abs(lasso_best.coef_)
coef = lasso_best.coef_
feature_names = train_X.columns
feature_importances= pd.DataFrame([feature_names,importance,coef]).T
feature_importances.columns = ['feature_names','coef_abs','coef']

feature_importances = feature_importances.sort_values(by='coef_abs',ascending=False)
feature_importances['Parent_feature']=feature_importances['feature_names'].apply(lambda x: x[0:x.find('_lag')] if x.find('_lag')!=-1 else x)
feature_importances['Parent_feature']=feature_importances['Parent_feature'].apply(lambda x: x[0:x.find('_diff')] if x.find('_diff')!=-1 else x)

# %%
feature_importances
# Out:
#                                         feature_names  coef_abs      coef  \
# 50                                           zri_lag1  1.029261  1.029261
# 52                                           zri_lag3  0.094326 -0.094326
# 53                                           zri_lag4  0.014765 -0.014765
# 224                                    fake news_lag3  0.006512  0.006512
# 183                multifamily_for_rent_searches_lag1  0.004906  0.004906
# 44                                       places to go  0.004255  0.004255
# 184                multifamily_for_rent_searches_lag2  0.003555  0.003555
# 207                                 places to go_lag1  0.003092  0.003092
# 186                                    lululemon_lag1   0.00169  -0.00169
# 37                                          lululemon  0.001012 -0.001012
# 220                                   retirement_lag2  0.000929  0.000929
# 208                                 places to go_lag2  0.000392  0.000392
# 153                            same sex marriage_lag1       0.0       0.0
# 150                                    hurricane_lag1       0.0       0.0
# 149                            job opportunities_lag3       0.0       0.0
# 148                            job opportunities_lag2       0.0       0.0
# 147                            job opportunities_lag1       0.0       0.0
# 152                                    hurricane_lag3       0.0       0.0
# 151                                    hurricane_lag2       0.0       0.0
# 155                            same sex marriage_lag3       0.0      -0.0
# 154                            same sex marriage_lag2       0.0      -0.0
# 145                     make america great again_lag2       0.0       0.0
# 156                                 unemployment_lag1       0.0      -0.0
# 157                                 unemployment_lag2       0.0      -0.0
# 158                                 unemployment_lag3       0.0      -0.0
# 159                                      twitter_lag1       0.0      -0.0
# 160                                      twitter_lag2       0.0      -0.0
# 161                                      twitter_lag3       0.0      -0.0
# 162                                         fire_lag1       0.0       0.0
# 163                                         fire_lag2       0.0       0.0
# 164                                         fire_lag3       0.0       0.0
# 165                        political correctness_lag1       0.0      -0.0
# 146                     make america great again_lag3       0.0       0.0
# 143                                       thrift_lag3       0.0      -0.0
# 144                     make america great again_lag1       0.0      -0.0
# 129                      percent_work_from_home_lag12       0.0       0.0
# 117                                  median_age_lag12       0.0       0.0
# 118                percent_associates_diff_lag1_lag12       0.0       0.0
# 119                           percent_associates_lag1       0.0       0.0
# 120                           percent_associates_lag6       0.0       0.0
# 121                          percent_associates_lag12       0.0       0.0
# 122                         total_pop_diff_lag1_lag12       0.0      -0.0
# 123                                    total_pop_lag1       0.0       0.0
# 124                                    total_pop_lag6       0.0       0.0
# 125                                   total_pop_lag12       0.0       0.0
# 126            percent_work_from_home_diff_lag1_lag12       0.0       0.0
# 127                       percent_work_from_home_lag1       0.0       0.0
# 128                       percent_work_from_home_lag6       0.0       0.0
# 130                            bs_total_stations_lag1       0.0       0.0
# 167                        political correctness_lag3       0.0      -0.0
# 131                 bs_total_stations_diff_lag1_lag12       0.0      -0.0
# 132                             state_local_perc_lag1       0.0      -0.0
# 133                  state_local_perc_diff_lag1_lag12       0.0       0.0
# 134                                startup_firms_lag1       0.0       0.0
# 135                     startup_firms_diff_lag1_lag12       0.0       0.0
# 136                                 net_job_rate_lag1       0.0      -0.0
# 137                      net_job_rate_diff_lag1_lag12       0.0      -0.0
# 138                  apartment_for_rent_searches_lag1       0.0       0.0
# 139                  apartment_for_rent_searches_lag2       0.0       0.0
# 140                  apartment_for_rent_searches_lag3       0.0       0.0
# 141                                       thrift_lag1       0.0       0.0
# 142                                       thrift_lag2       0.0       0.0
# 166                        political correctness_lag2       0.0      -0.0
# 173                                     pronouns_lag3       0.0      -0.0
# 168                                    starbucks_lag1       0.0       0.0
# 211                                     wildfire_lag2       0.0       0.0
# 199                                 gun_searches_lag2       0.0      -0.0
# 200                                 gun_searches_lag3       0.0      -0.0
# 201                                      hashtag_lag1       0.0       0.0
# 202                                      hashtag_lag2       0.0      -0.0
# 203                                      hashtag_lag3       0.0      -0.0
# 204                                       layoff_lag1       0.0       0.0
# 205                                       layoff_lag2       0.0       0.0
# 206                                       layoff_lag3       0.0       0.0
# 209                                 places to go_lag3       0.0       0.0
# 210                                     wildfire_lag1       0.0       0.0
# 212                                     wildfire_lag3       0.0      -0.0
# 197                                         lgbt_lag3       0.0       0.0
# 213                                      getaway_lag1       0.0       0.0
# 214                                      getaway_lag2       0.0       0.0
# 215                                      getaway_lag3       0.0       0.0
# 216                               flight tickets_lag1       0.0       0.0
# 217                               flight tickets_lag2       0.0       0.0
# 218                               flight tickets_lag3       0.0       0.0
# 219                                   retirement_lag1       0.0       0.0
# 221                                   retirement_lag3       0.0       0.0
# 222                                    fake news_lag1       0.0       0.0
# 223                                    fake news_lag2       0.0       0.0
# 198                                 gun_searches_lag1       0.0      -0.0
# 196                                         lgbt_lag2       0.0       0.0
# 169                                    starbucks_lag2       0.0      -0.0
# 180                                   euthanasia_lag1       0.0      -0.0
# 170                                    starbucks_lag3       0.0       0.0
# 171                                     pronouns_lag1       0.0      -0.0
# 172                                     pronouns_lag2       0.0      -0.0
# 115                                   median_age_lag1       0.0       0.0
# 174                           black lives matter_lag1       0.0      -0.0
# 175                           black lives matter_lag2       0.0      -0.0
# 176                           black lives matter_lag3       0.0      -0.0
# 177                                 trader joe's_lag1       0.0      -0.0
# 178                                 trader joe's_lag2       0.0       0.0
# 179                                 trader joe's_lag3       0.0       0.0
# 181                                   euthanasia_lag2       0.0       0.0
# 195                                         lgbt_lag1       0.0       0.0
# 182                                   euthanasia_lag3       0.0       0.0
# 185                multifamily_for_rent_searches_lag3       0.0       0.0
# 187                                    lululemon_lag2       0.0      -0.0
# 188                                    lululemon_lag3       0.0      -0.0
# 189                                        flood_lag1       0.0       0.0
# 190                                        flood_lag2       0.0       0.0
# 191                                        flood_lag3       0.0      -0.0
# 192                                  whole foods_lag1       0.0      -0.0
# 193                                  whole foods_lag2       0.0      -0.0
# 194                                  whole foods_lag3       0.0      -0.0
# 116                                   median_age_lag6       0.0       0.0
# 0                                        poverty_rate       0.0       0.0
# 114                        median_age_diff_lag1_lag12       0.0       0.0
# 41                                       gun_searches       0.0      -0.0
# 29                                               fire       0.0       0.0
# 30                              political correctness       0.0      -0.0
# 31                                          starbucks       0.0       0.0
# 32                                           pronouns       0.0      -0.0
# 33                                 black lives matter       0.0       0.0
# 34                                       trader joe's       0.0       0.0
# 35                                         euthanasia       0.0      -0.0
# 36                      multifamily_for_rent_searches       0.0       0.0
# 38                                              flood       0.0       0.0
# 39                                        whole foods       0.0      -0.0
# 40                                               lgbt       0.0       0.0
# 42                                            hashtag       0.0       0.0
# 59                                          zri_lag10       0.0       0.0
# 43                                             layoff       0.0      -0.0
# 45                                           wildfire       0.0       0.0
# 46                                            getaway       0.0       0.0
# 47                                     flight tickets       0.0       0.0
# 48                                         retirement       0.0       0.0
# 49                                          fake news       0.0       0.0
# 51                                           zri_lag2       0.0      -0.0
# 54                                           zri_lag5       0.0      -0.0
# 55                                           zri_lag6       0.0      -0.0
# 56                                           zri_lag7       0.0       0.0
# 57                                           zri_lag8       0.0       0.0
# 28                                            twitter       0.0      -0.0
# 27                                       unemployment       0.0      -0.0
# 26                                  same sex marriage       0.0       0.0
# 25                                          hurricane       0.0       0.0
# 2                                   income_per_capita       0.0       0.0
# 3                                  percent_highschool       0.0      -0.0
# 4                                 median_building_age       0.0       0.0
# 5                        percent_workforce_unemployed       0.0      -0.0
# 6                        percent_units_owner_occupied       0.0      -0.0
# 7                       percent_rental_units_occupied       0.0       0.0
# 8                                   percent_native_am       0.0      -0.0
# 9                                       percent_white       0.0      -0.0
# 10                   percent_commute_public_transport       0.0      -0.0
# 11                      percent_buildings_10_19_units       0.0       0.0
# 12                      percent_buildings_20_49_units       0.0      -0.0
# 13                                         median_age       0.0       0.0
# 14                                 percent_associates       0.0       0.0
# 15                                          total_pop       0.0       0.0
# 16                             percent_work_from_home       0.0       0.0
# 17                                  bs_total_stations       0.0       0.0
# 18                                   state_local_perc       0.0      -0.0
# 19                                      startup_firms       0.0       0.0
# 20                                       net_job_rate       0.0      -0.0
# 21                        apartment_for_rent_searches       0.0       0.0
# 22                                             thrift       0.0       0.0
# 23                           make america great again       0.0      -0.0
# 24                                  job opportunities       0.0      -0.0
# 58                                           zri_lag9       0.0       0.0
# 60                                          zri_lag11       0.0       0.0
# 113               percent_buildings_20_49_units_lag12       0.0       0.0
# 100                                percent_white_lag6       0.0      -0.0
# 89                 percent_units_owner_occupied_lag12       0.0      -0.0
# 90      percent_rental_units_occupied_diff_lag1_lag12       0.0       0.0
# 91                 percent_rental_units_occupied_lag1       0.0       0.0
# 92                 percent_rental_units_occupied_lag6       0.0       0.0
# 93                percent_rental_units_occupied_lag12       0.0       0.0
# 94                  percent_native_am_diff_lag1_lag12       0.0       0.0
# 95                             percent_native_am_lag1       0.0      -0.0
# 96                             percent_native_am_lag6       0.0      -0.0
# 97                            percent_native_am_lag12       0.0      -0.0
# 98                      percent_white_diff_lag1_lag12       0.0      -0.0
# 99                                 percent_white_lag1       0.0      -0.0
# 101                               percent_white_lag12       0.0      -0.0
# 61                                zri_diff_lag1_lag12       0.0       0.0
# 102  percent_commute_public_transport_diff_lag1_lag12       0.0      -0.0
# 103             percent_commute_public_transport_lag1       0.0      -0.0
# 104             percent_commute_public_transport_lag6       0.0      -0.0
# 105            percent_commute_public_transport_lag12       0.0      -0.0
# 106     percent_buildings_10_19_units_diff_lag1_lag12       0.0       0.0
# 107                percent_buildings_10_19_units_lag1       0.0       0.0
# 108                percent_buildings_10_19_units_lag6       0.0       0.0
# 109               percent_buildings_10_19_units_lag12       0.0      -0.0
# 110     percent_buildings_20_49_units_diff_lag1_lag12       0.0      -0.0
# 111                percent_buildings_20_49_units_lag1       0.0      -0.0
# 1                         percent_buildings_50+_units       0.0       0.0
# 88                  percent_units_owner_occupied_lag6       0.0      -0.0
# 87                  percent_units_owner_occupied_lag1       0.0      -0.0
# 86       percent_units_owner_occupied_diff_lag1_lag12       0.0       0.0
# 85                 percent_workforce_unemployed_lag12       0.0      -0.0
# 62                       poverty_rate_diff_lag1_lag12       0.0      -0.0
# 63                                  poverty_rate_lag1       0.0       0.0
# 64                                  poverty_rate_lag6       0.0       0.0
# 65                                 poverty_rate_lag12       0.0       0.0
# 66        percent_buildings_50+_units_diff_lag1_lag12       0.0       0.0
# 67                   percent_buildings_50+_units_lag1       0.0       0.0
# 68                   percent_buildings_50+_units_lag6       0.0       0.0
# 69                  percent_buildings_50+_units_lag12       0.0       0.0
# 70                  income_per_capita_diff_lag1_lag12       0.0       0.0
# 71                             income_per_capita_lag1       0.0       0.0
# 72                             income_per_capita_lag6       0.0       0.0
# 73                            income_per_capita_lag12       0.0      -0.0
# 74                 percent_highschool_diff_lag1_lag12       0.0       0.0
# 75                            percent_highschool_lag1       0.0      -0.0
# 76                            percent_highschool_lag6       0.0      -0.0
# 77                           percent_highschool_lag12       0.0      -0.0
# 78                median_building_age_diff_lag1_lag12       0.0      -0.0
# 79                           median_building_age_lag1       0.0       0.0
# 80                           median_building_age_lag6       0.0       0.0
# 81                          median_building_age_lag12       0.0       0.0
# 82       percent_workforce_unemployed_diff_lag1_lag12       0.0      -0.0
# 83                  percent_workforce_unemployed_lag1       0.0      -0.0
# 84                  percent_workforce_unemployed_lag6       0.0      -0.0
# 112                percent_buildings_20_49_units_lag6       0.0       0.0
#
#                        Parent_feature
# 50                                zri
# 52                                zri
# 53                                zri
# 224                         fake news
# 183     multifamily_for_rent_searches
# 44                       places to go
# 184     multifamily_for_rent_searches
# 207                      places to go
# 186                         lululemon
# 37                          lululemon
# 220                        retirement
# 208                      places to go
# 153                 same sex marriage
# 150                         hurricane
# 149                 job opportunities
# 148                 job opportunities
# 147                 job opportunities
# 152                         hurricane
# 151                         hurricane
# 155                 same sex marriage
# 154                 same sex marriage
# 145          make america great again
# 156                      unemployment
# 157                      unemployment
# 158                      unemployment
# 159                           twitter
# 160                           twitter
# 161                           twitter
# 162                              fire
# 163                              fire
# 164                              fire
# 165             political correctness
# 146          make america great again
# 143                            thrift
# 144          make america great again
# 129            percent_work_from_home
# 117                        median_age
# 118                percent_associates
# 119                percent_associates
# 120                percent_associates
# 121                percent_associates
# 122                         total_pop
# 123                         total_pop
# 124                         total_pop
# 125                         total_pop
# 126            percent_work_from_home
# 127            percent_work_from_home
# 128            percent_work_from_home
# 130                 bs_total_stations
# 167             political correctness
# 131                 bs_total_stations
# 132                  state_local_perc
# 133                  state_local_perc
# 134                     startup_firms
# 135                     startup_firms
# 136                      net_job_rate
# 137                      net_job_rate
# 138       apartment_for_rent_searches
# 139       apartment_for_rent_searches
# 140       apartment_for_rent_searches
# 141                            thrift
# 142                            thrift
# 166             political correctness
# 173                          pronouns
# 168                         starbucks
# 211                          wildfire
# 199                      gun_searches
# 200                      gun_searches
# 201                           hashtag
# 202                           hashtag
# 203                           hashtag
# 204                            layoff
# 205                            layoff
# 206                            layoff
# 209                      places to go
# 210                          wildfire
# 212                          wildfire
# 197                              lgbt
# 213                           getaway
# 214                           getaway
# 215                           getaway
# 216                    flight tickets
# 217                    flight tickets
# 218                    flight tickets
# 219                        retirement
# 221                        retirement
# 222                         fake news
# 223                         fake news
# 198                      gun_searches
# 196                              lgbt
# 169                         starbucks
# 180                        euthanasia
# 170                         starbucks
# 171                          pronouns
# 172                          pronouns
# 115                        median_age
# 174                black lives matter
# 175                black lives matter
# 176                black lives matter
# 177                      trader joe's
# 178                      trader joe's
# 179                      trader joe's
# 181                        euthanasia
# 195                              lgbt
# 182                        euthanasia
# 185     multifamily_for_rent_searches
# 187                         lululemon
# 188                         lululemon
# 189                             flood
# 190                             flood
# 191                             flood
# 192                       whole foods
# 193                       whole foods
# 194                       whole foods
# 116                        median_age
# 0                        poverty_rate
# 114                        median_age
# 41                       gun_searches
# 29                               fire
# 30              political correctness
# 31                          starbucks
# 32                           pronouns
# 33                 black lives matter
# 34                       trader joe's
# 35                         euthanasia
# 36      multifamily_for_rent_searches
# 38                              flood
# 39                        whole foods
# 40                               lgbt
# 42                            hashtag
# 59                                zri
# 43                             layoff
# 45                           wildfire
# 46                            getaway
# 47                     flight tickets
# 48                         retirement
# 49                          fake news
# 51                                zri
# 54                                zri
# 55                                zri
# 56                                zri
# 57                                zri
# 28                            twitter
# 27                       unemployment
# 26                  same sex marriage
# 25                          hurricane
# 2                   income_per_capita
# 3                  percent_highschool
# 4                 median_building_age
# 5        percent_workforce_unemployed
# 6        percent_units_owner_occupied
# 7       percent_rental_units_occupied
# 8                   percent_native_am
# 9                       percent_white
# 10   percent_commute_public_transport
# 11      percent_buildings_10_19_units
# 12      percent_buildings_20_49_units
# 13                         median_age
# 14                 percent_associates
# 15                          total_pop
# 16             percent_work_from_home
# 17                  bs_total_stations
# 18                   state_local_perc
# 19                      startup_firms
# 20                       net_job_rate
# 21        apartment_for_rent_searches
# 22                             thrift
# 23           make america great again
# 24                  job opportunities
# 58                                zri
# 60                                zri
# 113     percent_buildings_20_49_units
# 100                     percent_white
# 89       percent_units_owner_occupied
# 90      percent_rental_units_occupied
# 91      percent_rental_units_occupied
# 92      percent_rental_units_occupied
# 93      percent_rental_units_occupied
# 94                  percent_native_am
# 95                  percent_native_am
# 96                  percent_native_am
# 97                  percent_native_am
# 98                      percent_white
# 99                      percent_white
# 101                     percent_white
# 61                                zri
# 102  percent_commute_public_transport
# 103  percent_commute_public_transport
# 104  percent_commute_public_transport
# 105  percent_commute_public_transport
# 106     percent_buildings_10_19_units
# 107     percent_buildings_10_19_units
# 108     percent_buildings_10_19_units
# 109     percent_buildings_10_19_units
# 110     percent_buildings_20_49_units
# 111     percent_buildings_20_49_units
# 1         percent_buildings_50+_units
# 88       percent_units_owner_occupied
# 87       percent_units_owner_occupied
# 86       percent_units_owner_occupied
# 85       percent_workforce_unemployed
# 62                       poverty_rate
# 63                       poverty_rate
# 64                       poverty_rate
# 65                       poverty_rate
# 66        percent_buildings_50+_units
# 67        percent_buildings_50+_units
# 68        percent_buildings_50+_units
# 69        percent_buildings_50+_units
# 70                  income_per_capita
# 71                  income_per_capita
# 72                  income_per_capita
# 73                  income_per_capita
# 74                 percent_highschool
# 75                 percent_highschool
# 76                 percent_highschool
# 77                 percent_highschool
# 78                median_building_age
# 79                median_building_age
# 80                median_building_age
# 81                median_building_age
# 82       percent_workforce_unemployed
# 83       percent_workforce_unemployed
# 84       percent_workforce_unemployed
# 112     percent_buildings_20_49_units

# %%
feats_agg = feature_importances[['coef_abs','Parent_feature']]
feats_agg['coef_abs'] = feats_agg['coef_abs'].astype('float')
feats_agg_abs = feats_agg.groupby('Parent_feature').agg('mean').sort_values('coef_abs',ascending=False)
feats_agg_abs
# Out:
# <ipython-input-45-0836822478da>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feats_agg['coef_abs'] = feats_agg['coef_abs'].astype('float')
#                                   coef_abs
# Parent_feature
# zri                               0.094863
# multifamily_for_rent_searches     0.002115
# places to go                      0.001935
# fake news                         0.001628
# lululemon                         0.000675
# retirement                        0.000232
# percent_rental_units_occupied     0.000000
# percent_units_owner_occupied      0.000000
# percent_white                     0.000000
# percent_work_from_home            0.000000
# percent_workforce_unemployed      0.000000
# political correctness             0.000000
# poverty_rate                      0.000000
# pronouns                          0.000000
# same sex marriage                 0.000000
# percent_highschool                0.000000
# starbucks                         0.000000
# startup_firms                     0.000000
# state_local_perc                  0.000000
# thrift                            0.000000
# total_pop                         0.000000
# trader joe's                      0.000000
# twitter                           0.000000
# unemployment                      0.000000
# whole foods                       0.000000
# wildfire                          0.000000
# percent_native_am                 0.000000
# apartment_for_rent_searches       0.000000
# percent_commute_public_transport  0.000000
# income_per_capita                 0.000000
# bs_total_stations                 0.000000
# euthanasia                        0.000000
# fire                              0.000000
# flight tickets                    0.000000
# flood                             0.000000
# getaway                           0.000000
# gun_searches                      0.000000
# hashtag                           0.000000
# hurricane                         0.000000
# job opportunities                 0.000000
# black lives matter                0.000000
# layoff                            0.000000
# lgbt                              0.000000
# make america great again          0.000000
# median_age                        0.000000
# median_building_age               0.000000
# net_job_rate                      0.000000
# percent_associates                0.000000
# percent_buildings_10_19_units     0.000000
# percent_buildings_20_49_units     0.000000
# percent_buildings_50+_units       0.000000

# %%
title = 'FINAL_3_Auto_All'
fi = title+'_FI'
fi2 = title+'_FI_Agg_sign'
# rstable.to_csv(f'../../../zillow_orientation/Residuals/{title}.csv')
# feature_importances.to_csv(f'../../../zillow_orientation/Residuals/{fi}.csv')
# feats_agg_abs.to_csv(f'../../../zillow_orientation/Residuals/{fi2}.csv')

# %%
# R2: 96.78959391649265
# RMSE: 119.20767979158444
# alpha: 0.01

# %%
rstable
# Out:
#          zip  zri_test  zri_predicted
# 0       1013    1099.0    1104.739851
# 1      14850    1545.0    1597.069313
# 2       6114    1139.0    1092.595199
# 3      90804    1957.0    1808.995912
# 4      59601     845.4     843.381935
# ...      ...       ...            ...
# 15607  14217     901.0     923.533427
# 15608  60611    2138.0    2240.269399
# 15609  93307     883.0     899.062315
# 15610  10019    3619.0    3745.236626
# 15611  99654    1224.0    1345.270713
#
# [15612 rows x 3 columns]

# %%
rstable['residual']=rstable['zri_predicted']-rstable['zri_test']
rstable['residual_squared']=rstable['residual'].map(lambda x: x**2)
rstable
# Out:
#          zip  zri_test  zri_predicted    residual  residual_squared
# 0       1013    1099.0    1104.739851    5.739851         32.945891
# 1      14850    1545.0    1597.069313   52.069313       2711.213399
# 2       6114    1139.0    1092.595199  -46.404801       2153.405570
# 3      90804    1957.0    1808.995912 -148.004088      21905.210126
# 4      59601     845.4     843.381935   -2.018065          4.072586
# ...      ...       ...            ...         ...               ...
# 15607  14217     901.0     923.533427   22.533427        507.755310
# 15608  60611    2138.0    2240.269399  102.269399      10459.029886
# 15609  93307     883.0     899.062315   16.062315        257.997975
# 15610  10019    3619.0    3745.236626  126.236626      15935.685619
# 15611  99654    1224.0    1345.270713  121.270713      14706.585715
#
# [15612 rows x 5 columns]

# %%
rmse_table=rstable.groupby('zip')[['residual_squared']].agg(['sum','count'])
rmse_table['residual_avgd']=rmse_table['residual_squared']['sum']/rmse_table['residual_squared']['count']
rmse_table['residual_avgd']=rmse_table['residual_avgd'].apply(lambda x: x**0.5)
rmse_table['residual_avgd'].mean()
# Out:
# 97.04144335035538

# %%
rmse_table
# Out:
#       residual_squared       residual_avgd
#                    sum count
# zip
# 1013      17740.160245    12     38.449274
# 1020      56314.963109    12     68.504844
# 1040      35119.644684    12     54.098402
# 1085      33934.647547    12     53.177884
# 1104      29247.880239    12     49.369255
# ...                ...   ...           ...
# 99207    270990.441717    12    150.274871
# 99501     63730.771843    12     72.875906
# 99504    129130.050462    12    103.734457
# 99508     68081.760726    12     75.322507
# 99654     51232.479895    12     65.340442
#
# [1301 rows x 3 columns]

# %%
#RESULTS 
r2 = r2_score(rstable['zri_test'],rstable['zri_predicted'])
rmse = sqrt(mean_squared_error(rstable['zri_test'],rstable['zri_predicted']))
print(f'R2: {r2*100}')
print(f'RMSE: {rmse}')
# Out:
# R2: 96.78959391649265
# RMSE: 119.20767979158444

# %%
# rstable.to_csv(f'../../../zillow_orientation/Residuals/{title}_rstable.csv')
# rmse_table.to_csv(f'../../../zillow_orientation/Residuals/{title}_rmse.csv')
