# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np

def time_series_gaps(df, ts_start_col):
    '''
    Returns a dictionary containing:
        keys: the row indices of any row with missing data
        values: numeric horizontal (column) start and end indices of any periods of missing data
    
    time series data must be running row-wise for the function to work
    
    ts_start_col is the numeric index of the column in the dataframe at which the time series begins
    the function assumes the time series runs from ts_start_col all the way to the right side of the dataframe
    '''
    gaps = {}
    for i in range(df.shape[0]):
        curr_gaps = []
        curr_ts = df.iloc[i,:]
        if curr_ts.isnull().any():
            j = ts_start_col
            while j < len(curr_ts):
                if pd.isnull(curr_ts[j]):
                    gap_start = int(j)
                    gap_end = None
                    k = int(j)
                    while gap_end is None:
                        if k == len(curr_ts) - 1:
                            if pd.isnull(curr_ts[k]):
                                gap_end = int(k)
                                curr_gaps.append((gap_start, gap_end))
                                j = int(k)+1
                            else:   
                                gap_end = int(k) - 1
                                curr_gaps.append((gap_start, gap_end))
                                j = int(k)+1
                        elif pd.isnull(curr_ts[k]):
                            k+=1
                        else:
                            gap_end = int(k) - 1
                            curr_gaps.append((gap_start, gap_end))
                            j = int(k)
                else:
                    j += 1
        if curr_gaps != []:
            gaps[i] = curr_gaps
    return gaps

def get_rejected_gaps(gaps, gap_limit):
    '''
    takes gaps dictionary generated by time_series_gaps, returns list of row indices that contain gaps >= gap_limit
    '''
    over_limit = []
    for key, val in gaps.items():
        if len(val) > 1:
            for i in range(len(val)):
                width = val[i][1] - val[i][0] + 1
                if width >= gap_limit:
                    over_limit.append(key)
        else:
            width = val[0][1] - val[0][0] + 1
            if width >= gap_limit:
                over_limit.append(key)
    return list(set(over_limit))

# %%
multi = pd.read_csv('./../data/Zip_Zri_MultiFamilyResidenceRental.csv')

# %%
type(multi['RegionName'][0])
# Out:
# numpy.int64

# %%
multi
# Out:
#       RegionID  RegionName            City State  \
# 0        61639       10025        New York    NY
# 1        84654       60657         Chicago    IL
# 2        61637       10023        New York    NY
# 3        91982       77494            Katy    TX
# 4        84616       60614         Chicago    IL
# ...        ...         ...             ...   ...
# 1856     90755       75202          Dallas    TX
# 1857     94610       84627         Ephraim    UT
# 1858     84452       60301        Oak Park    IL
# 1859     94629       84647  Mount Pleasant    UT
# 1860     91695       77046         Houston    TX
#
#                                  Metro       CountyName  SizeRank  2010-09  \
# 0          New York-Newark-Jersey City  New York County         1   2930.0
# 1             Chicago-Naperville-Elgin      Cook County         2   1447.0
# 2          New York-Newark-Jersey City  New York County         3   2797.0
# 3     Houston-The Woodlands-Sugar Land    Harris County         4      NaN
# 4             Chicago-Naperville-Elgin      Cook County         5   1437.0
# ...                                ...              ...       ...      ...
# 1856       Dallas-Fort Worth-Arlington    Dallas County      1857    997.0
# 1857                               NaN   Sanpete County      1858      NaN
# 1858          Chicago-Naperville-Elgin      Cook County      1859      NaN
# 1859                               NaN   Sanpete County      1860      NaN
# 1860  Houston-The Woodlands-Sugar Land    Harris County      1861      NaN
#
#       2010-10  2010-11  ...  2019-04  2019-05  2019-06  2019-07  2019-08  \
# 0      2952.0   2926.0  ...   3484.0   3523.0   3573.0   3622.0   3664.0
# 1      1465.0   1469.0  ...   1731.0   1749.0   1768.0   1787.0   1801.0
# 2      2811.0   2813.0  ...   3449.0   3459.0   3479.0   3491.0   3510.0
# 3         NaN      NaN  ...   1226.0   1250.0   1264.0   1251.0   1246.0
# 4      1469.0   1490.0  ...   1888.0   1911.0   1934.0   1950.0   1953.0
# ...       ...      ...  ...      ...      ...      ...      ...      ...
# 1856   1019.0   1042.0  ...   1615.0   1619.0   1628.0      NaN      NaN
# 1857      NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
# 1858      NaN      NaN  ...   1447.0   1483.0   1495.0   1511.0   1537.0
# 1859      NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
# 1860      NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
#
#       2019-09  2019-10  2019-11  2019-12  2020-01
# 0      3698.0   3704.0   3692.0   3715.0   3676.0
# 1      1806.0   1789.0   1761.0   1747.0   1731.0
# 2      3521.0   3574.0   3608.0   3561.0      NaN
# 3      1252.0   1280.0   1310.0   1294.0   1286.0
# 4      1952.0   1921.0   1958.0      NaN   1916.0
# ...       ...      ...      ...      ...      ...
# 1856   1729.0   1697.0   1739.0      NaN      NaN
# 1857      NaN      NaN      NaN   1298.0      NaN
# 1858   1570.0   1580.0   1625.0      NaN      NaN
# 1859      NaN      NaN      NaN      NaN   1221.0
# 1860      NaN      NaN      NaN      NaN      NaN
#
# [1861 rows x 120 columns]

# %%
multi['RegionName'] = multi['RegionName'].map(lambda x: str(x))

# %%
multi['RegionName'].map(lambda x: len(x)).value_counts()
# Out:
# 5    1621
# 4     240
# Name: RegionName, dtype: int64

# %%
multi['RegionName'] = multi['RegionName'].map(lambda x: '0'+x if len(x)<5 else x)

# %%
multi.rename(columns = {'RegionName':'zip'}, inplace = True)

# %%
multi = multi.iloc[:,1:] # drop RegionID column, just a unique identifier

# %%
multi
# Out:
#         zip            City State                             Metro  \
# 0     10025        New York    NY       New York-Newark-Jersey City
# 1     60657         Chicago    IL          Chicago-Naperville-Elgin
# 2     10023        New York    NY       New York-Newark-Jersey City
# 3     77494            Katy    TX  Houston-The Woodlands-Sugar Land
# 4     60614         Chicago    IL          Chicago-Naperville-Elgin
# ...     ...             ...   ...                               ...
# 1856  75202          Dallas    TX       Dallas-Fort Worth-Arlington
# 1857  84627         Ephraim    UT                               NaN
# 1858  60301        Oak Park    IL          Chicago-Naperville-Elgin
# 1859  84647  Mount Pleasant    UT                               NaN
# 1860  77046         Houston    TX  Houston-The Woodlands-Sugar Land
#
#            CountyName  SizeRank  2010-09  2010-10  2010-11  2010-12  ...  \
# 0     New York County         1   2930.0   2952.0   2926.0   2904.0  ...
# 1         Cook County         2   1447.0   1465.0   1469.0   1467.0  ...
# 2     New York County         3   2797.0   2811.0   2813.0   2784.0  ...
# 3       Harris County         4      NaN      NaN      NaN      NaN  ...
# 4         Cook County         5   1437.0   1469.0   1490.0   1503.0  ...
# ...               ...       ...      ...      ...      ...      ...  ...
# 1856    Dallas County      1857    997.0   1019.0   1042.0   1063.0  ...
# 1857   Sanpete County      1858      NaN      NaN      NaN      NaN  ...
# 1858      Cook County      1859      NaN      NaN      NaN      NaN  ...
# 1859   Sanpete County      1860      NaN      NaN      NaN      NaN  ...
# 1860    Harris County      1861      NaN      NaN      NaN      NaN  ...
#
#       2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  \
# 0      3484.0   3523.0   3573.0   3622.0   3664.0   3698.0   3704.0   3692.0
# 1      1731.0   1749.0   1768.0   1787.0   1801.0   1806.0   1789.0   1761.0
# 2      3449.0   3459.0   3479.0   3491.0   3510.0   3521.0   3574.0   3608.0
# 3      1226.0   1250.0   1264.0   1251.0   1246.0   1252.0   1280.0   1310.0
# 4      1888.0   1911.0   1934.0   1950.0   1953.0   1952.0   1921.0   1958.0
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1856   1615.0   1619.0   1628.0      NaN      NaN   1729.0   1697.0   1739.0
# 1857      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1858   1447.0   1483.0   1495.0   1511.0   1537.0   1570.0   1580.0   1625.0
# 1859      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1860      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#       2019-12  2020-01
# 0      3715.0   3676.0
# 1      1747.0   1731.0
# 2      3561.0      NaN
# 3      1294.0   1286.0
# 4         NaN   1916.0
# ...       ...      ...
# 1856      NaN      NaN
# 1857   1298.0      NaN
# 1858      NaN      NaN
# 1859      NaN   1221.0
# 1860      NaN      NaN
#
# [1861 rows x 119 columns]

# %%
multi = pd.concat([multi.iloc[:,0:6], multi.iloc[:,46:]], axis = 1)

# %%
multi
# Out:
#         zip            City State                             Metro  \
# 0     10025        New York    NY       New York-Newark-Jersey City
# 1     60657         Chicago    IL          Chicago-Naperville-Elgin
# 2     10023        New York    NY       New York-Newark-Jersey City
# 3     77494            Katy    TX  Houston-The Woodlands-Sugar Land
# 4     60614         Chicago    IL          Chicago-Naperville-Elgin
# ...     ...             ...   ...                               ...
# 1856  75202          Dallas    TX       Dallas-Fort Worth-Arlington
# 1857  84627         Ephraim    UT                               NaN
# 1858  60301        Oak Park    IL          Chicago-Naperville-Elgin
# 1859  84647  Mount Pleasant    UT                               NaN
# 1860  77046         Houston    TX  Houston-The Woodlands-Sugar Land
#
#            CountyName  SizeRank  2014-01  2014-02  2014-03  2014-04  ...  \
# 0     New York County         1   3333.0   3338.0   3340.0   3323.0  ...
# 1         Cook County         2   1647.0   1645.0   1635.0   1650.0  ...
# 2     New York County         3   3135.0   3138.0   3136.0   3131.0  ...
# 3       Harris County         4      NaN      NaN   1081.0   1093.0  ...
# 4         Cook County         5   1756.0   1759.0   1754.0   1774.0  ...
# ...               ...       ...      ...      ...      ...      ...  ...
# 1856    Dallas County      1857   1297.0   1284.0   1295.0   1297.0  ...
# 1857   Sanpete County      1858      NaN      NaN      NaN      NaN  ...
# 1858      Cook County      1859      NaN      NaN      NaN      NaN  ...
# 1859   Sanpete County      1860      NaN      NaN      NaN      NaN  ...
# 1860    Harris County      1861      NaN      NaN      NaN      NaN  ...
#
#       2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  \
# 0      3484.0   3523.0   3573.0   3622.0   3664.0   3698.0   3704.0   3692.0
# 1      1731.0   1749.0   1768.0   1787.0   1801.0   1806.0   1789.0   1761.0
# 2      3449.0   3459.0   3479.0   3491.0   3510.0   3521.0   3574.0   3608.0
# 3      1226.0   1250.0   1264.0   1251.0   1246.0   1252.0   1280.0   1310.0
# 4      1888.0   1911.0   1934.0   1950.0   1953.0   1952.0   1921.0   1958.0
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1856   1615.0   1619.0   1628.0      NaN      NaN   1729.0   1697.0   1739.0
# 1857      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1858   1447.0   1483.0   1495.0   1511.0   1537.0   1570.0   1580.0   1625.0
# 1859      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1860      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#       2019-12  2020-01
# 0      3715.0   3676.0
# 1      1747.0   1731.0
# 2      3561.0      NaN
# 3      1294.0   1286.0
# 4         NaN   1916.0
# ...       ...      ...
# 1856      NaN      NaN
# 1857   1298.0      NaN
# 1858      NaN      NaN
# 1859      NaN   1221.0
# 1860      NaN      NaN
#
# [1861 rows x 79 columns]

# %%
gaps = time_series_gaps(multi, 7)

# %%
rej_gaps = get_rejected_gaps(gaps, 6)

# %%
multi2 = multi.drop(rej_gaps, axis = 0)

# %%
multi2
# Out:
#         zip         City State                             Metro  \
# 0     10025     New York    NY       New York-Newark-Jersey City
# 1     60657      Chicago    IL          Chicago-Naperville-Elgin
# 2     10023     New York    NY       New York-Newark-Jersey City
# 3     77494         Katy    TX  Houston-The Woodlands-Sugar Land
# 4     60614      Chicago    IL          Chicago-Naperville-Elgin
# ...     ...          ...   ...                               ...
# 1849  04937    Fairfield    ME                               NaN
# 1850  60606      Chicago    IL          Chicago-Naperville-Elgin
# 1852  12307  Schenectady    NY           Albany-Schenectady-Troy
# 1855  18232     Lansford    PA        Allentown-Bethlehem-Easton
# 1856  75202       Dallas    TX       Dallas-Fort Worth-Arlington
#
#               CountyName  SizeRank  2014-01  2014-02  2014-03  2014-04  ...  \
# 0        New York County         1   3333.0   3338.0   3340.0   3323.0  ...
# 1            Cook County         2   1647.0   1645.0   1635.0   1650.0  ...
# 2        New York County         3   3135.0   3138.0   3136.0   3131.0  ...
# 3          Harris County         4      NaN      NaN   1081.0   1093.0  ...
# 4            Cook County         5   1756.0   1759.0   1754.0   1774.0  ...
# ...                  ...       ...      ...      ...      ...      ...  ...
# 1849     Somerset County      1850    794.0    793.0    790.0    792.0  ...
# 1850         Cook County      1851   2004.0   2001.0   2016.0   2041.0  ...
# 1852  Schenectady County      1853      NaN   1044.0      NaN   1028.0  ...
# 1855       Carbon County      1856    775.0    778.0    780.0    783.0  ...
# 1856       Dallas County      1857   1297.0   1284.0   1295.0   1297.0  ...
#
#       2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  \
# 0      3484.0   3523.0   3573.0   3622.0   3664.0   3698.0   3704.0   3692.0
# 1      1731.0   1749.0   1768.0   1787.0   1801.0   1806.0   1789.0   1761.0
# 2      3449.0   3459.0   3479.0   3491.0   3510.0   3521.0   3574.0   3608.0
# 3      1226.0   1250.0   1264.0   1251.0   1246.0   1252.0   1280.0   1310.0
# 4      1888.0   1911.0   1934.0   1950.0   1953.0   1952.0   1921.0   1958.0
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1849   1092.0   1111.0   1108.0   1105.0   1113.0   1113.0   1146.0      NaN
# 1850   2145.0   2155.0   2166.0   2183.0   2206.0   2228.0   2217.0   2230.0
# 1852    937.0    949.0    964.0    974.0    978.0    978.0      NaN      NaN
# 1855    781.0    773.0    769.0    762.0    758.0    758.0      NaN      NaN
# 1856   1615.0   1619.0   1628.0      NaN      NaN   1729.0   1697.0   1739.0
#
#       2019-12  2020-01
# 0      3715.0   3676.0
# 1      1747.0   1731.0
# 2      3561.0      NaN
# 3      1294.0   1286.0
# 4         NaN   1916.0
# ...       ...      ...
# 1849      NaN      NaN
# 1850   2200.0   2192.0
# 1852   1039.0   1047.0
# 1855      NaN      NaN
# 1856      NaN      NaN
#
# [1302 rows x 79 columns]

# %%
multi2.columns[7:]
# Out:
# Index(['2014-02', '2014-03', '2014-04', '2014-05', '2014-06', '2014-07',
#        '2014-08', '2014-09', '2014-10', '2014-11', '2014-12', '2015-01',
#        '2015-02', '2015-03', '2015-04', '2015-05', '2015-06', '2015-07',
#        '2015-08', '2015-09', '2015-10', '2015-11', '2015-12', '2016-01',
#        '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07',
#        '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01',
#        '2017-02', '2017-03', '2017-04', '2017-05', '2017-06', '2017-07',
#        '2017-08', '2017-09', '2017-10', '2017-11', '2017-12', '2018-01',
#        '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07',
#        '2018-08', '2018-09', '2018-10', '2018-11', '2018-12', '2019-01',
#        '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07',
#        '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2020-01'],
#       dtype='object')

# %%
multi2.to_csv('../../data/HIER_zri_multifamily_v2.csv', index = False)

# %%
multi2 = pd.melt(multi2, id_vars = multi2.columns[0:6], value_vars = multi2.columns[6:], var_name = 'year-month', value_name = 'zri')

# %%
missing_zri = multi2[multi2['zri'].isnull()]['zip'].unique()

# %%
missing_zri
# Out:
# array(['77494', '10002', '78660', '94109', '77584', '28269', '94565',
#        '37042', '77429', '30044', '30043', '30024', '77077', '78666',
#        '78521', '75243', '94110', '44035', '07302', '37075', '19143',
#        '97229', '75056', '89108', '78240', '87111', '14850', '33024',
#        '98012', '92677', '20906', '10468', '60634', '22191', '07002',
#        '89052', '89117', '30080', '21117', '60628', '02360', '95123',
#        '27703', '23454', '85705', '20147', '90025', '20878', '27713',
#        '29464', '20019', '33313', '98115', '94568', '19124', '95051',
#        '32225', '76116', '23452', '60615', '78249', '77057', '27707',
#        '46143', '98133', '19120', '37040', '27705', '93309', '85282',
#        '28216', '94538', '33157', '33511', '85204', '59901', '21061',
#        '33414', '95014', '53704', '28210', '32771', '92130', '33433',
#        '92122', '19148', '76137', '78759', '94087', '97124', '33436',
#        '76051', '98034', '54601', '19131', '92117', '85201', '78209',
#        '94086', '94806', '19144', '92128', '92805', '33308', '30319',
#        '33312', '29414', '60402', '95008', '27606', '92656', '19146',
#        '19140', '29607', '89119', '30606', '26003', '27613', '77042',
#        '60630', '94115', '19464', '90024', '72764', '11224', '78216',
#        '28262', '85016', '27513', '01844', '27615', '92103', '75063',
#        '73071', '32837', '85224', '37221', '80211', '12866', '27612',
#        '33617', '78233', '92507', '14150', '85283', '33062', '91367',
#        '95831', '19139', '48235', '10312', '53215', '30328', '26505',
#        '92780', '53703', '60632', '53202', '85018', '85260', '85719',
#        '23602', '14224', '85044', '75248', '60201', '23803', '20902',
#        '21043', '80233', '92692', '06460', '59718', '27609', '30097',
#        '30339', '78201', '07960', '78213', '32224', '19128', '80210',
#        '78229', '94103', '33435', '76108', '44720', '80401', '90045',
#        '85020', '20176', '94107', '30350', '94010', '13440', '77090',
#        '53590', '92691', '06484', '93010', '53207', '44109', '97030',
#        '77004', '78744', '60645', '33196', '33461', '94025', '14701',
#        '12603', '85027', '97477', '28273', '01085', '85716', '92660',
#        '22901', '85015', '80205', '95826', '80021', '91764', '32207',
#        '33401', '80203', '75050', '60563', '60540', '27560', '32811',
#        '94901', '60653', '91913', '90815', '34232', '30305', '46219',
#        '94040', '72712', '75081', '11237', '94404', '95928', '60644',
#        '96826', '77006', '95050', '30338', '80204', '90069', '23831',
#        '33613', '78749', '17404', '32209', '93030', '98056', '37214',
#        '80112', '55414', '60607', '01760', '97209', '40391', '33010',
#        '01545', '18018', '77054', '12590', '84106', '10455', '13501',
#        '97214', '78729', '54901', '02864', '92612', '59801', '33756',
#        '32812', '34208', '32250', '11590', '60202', '59601', '21217',
#        '80503', '30046', '30341', '32205', '80027', '33140', '13502',
#        '95128', '90012', '04103', '33404', '78210', '92707', '30308',
#        '06053', '91505', '33334', '90068', '91107', '77380', '85014',
#        '90807', '98201', '20007', '33432', '06489', '95116', '22102',
#        '98444', '06614', '19141', '80202', '80111', '75039', '77019',
#        '84403', '76543', '55404', '98499', '23518', '90038', '98119',
#        '02062', '80120', '66213', '91355', '92108', '73159', '15217',
#        '80237', '80214', '99207', '94903', '80218', '33407', '43212',
#        '78212', '12303', '44052', '33626', '17022', '78728', '06051',
#        '02176', '91776', '98466', '30306', '72205', '80301', '06824',
#        '97062', '92123', '98029', '01876', '98498', '29205', '02131',
#        '92008', '02302', '01845', '95816', '55403', '84103', '80129',
#        '94549', '90023', '02132', '91106', '33701', '97035', '99654',
#        '33607', '92602', '90302', '76012', '33510', '15216', '92663',
#        '78702', '64111', '15210', '90015', '01880', '78757', '91101',
#        '95117', '43206', '53403', '92782', '30345', '98405', '90404',
#        '60636', '20740', '28202', '98409', '32803', '92673', '33301',
#        '32801', '31401', '21202', '90041', '04101', '67218', '33066',
#        '02026', '34210', '75001', '33916', '19107', '66223', '84102',
#        '33602', '33444', '14228', '78735', '10471', '97239', '14020',
#        '06108', '78754', '01104', '33132', '94085', '44108', '94703',
#        '19123', '22209', '01440', '92832', '78752', '01843', '53143',
#        '12304', '75235', '96150', '80915', '98005', '19106', '94105',
#        '02129', '99501', '04102', '13206', '33634', '06112', '55401',
#        '12508', '02476', '92603', '02451', '11010', '22305', '63105',
#        '76015', '06515', '90304', '16502', '55306', '10960', '12182',
#        '55413', '91105', '21046', '30326', '78256', '75244', '11426',
#        '55101', '11428', '02458', '94158', '02111', '10528', '06608',
#        '32204', '02113', '11366', '12202', '12209', '14209', '02494',
#        '06710', '33973', '02460', '14208', '06906', '02210', '06855',
#        '06607', '12307', '98052', '78704', '06902', '22304', '60622',
#        '23451', '75070', '78748', '60608', '19104', '92620', '95112',
#        '02135', '90036', '90028', '30093', '32835', '22202', '19130',
#        '76107', '32714', '33131', '22033', '98121', '06106', '01702',
#        '02446', '95134', '02453', '02474', '02215', '02134', '02478',
#        '01108', '06114', '33606', '78751', '06605', '02445', '64834',
#        '90280', '14221', '90640', '90255', '90022', '90723', '90262',
#        '90031', '12306', '13903', '16503', '12180', '02128', '02150',
#        '90220', '90221', '12206', '90270', '02124', '02136', '80033',
#        '02121', '02126', '02152', '63130', '90001', '02122', '02148',
#        '02155', '90011', '02151', '04401', '17701', '52001', '02703',
#        '94403', '01752', '02149', '76522', '94608', '20814', '01852',
#        '94401', '02840', '90002', '01851', '01854', '14216', '10310',
#        '78701', '01850', '12210', '77845', '90291', '90405', '14207',
#        '14213', '13205', '14301', '14201', '18232', '10009', '10128',
#        '10028', '29615', '10022', '43201', '80231', '60612', '94061',
#        '38104', '90063', '14621', '02721', '02891', '06830', '21231',
#        '02723', '10011', '10036', '10013', '10075', '94530', '01550',
#        '13760', '34207', '10017', '94801', '46208', '30318', '77840',
#        '17552', '44103', '29403', '65203', '02860', '90065', '02909',
#        '02904', '02861', '02905', '66214', '75052', '11229', '65201',
#        '33907', '53140', '14620', '97401', '10306', '90813', '10304',
#        '02908', '10305', '43202', '94621', '02914', '02907', '02910',
#        '14211', '14222', '10314', '45840', '58104', '02920', '33137',
#        '94603', '43205', '10302', '14210', '37211', '02301', '97501',
#        '04240', '30310', '66215', '47408', '04210', '63115', '94501',
#        '22903', '37115', '89101', '01841', '77550', '12047', '12189',
#        '60616', '37076', '55408', '64804', '64801', '03103', '03102',
#        '03104', '03060', '90062', '64836', '10303', '64870', '90802',
#        '12203', '44112', '13204', '78753', '33460', '02863', '02780',
#        '90803', '55407', '63107', '85281', '94541', '55104', '95207',
#        '54220', '02746', '19007', '85032', '43055', '85008', '02895',
#        '55418', '55411', '01757', '02143', '01801', '77598', '20009',
#        '32935', '75214', '91205', '02184', '90048', '92648', '01902',
#        '30309', '01420', '10029', '02120', '66061', '91801', '92410',
#        '03301', '10453', '10014', '90003', '10012', '20020', '10977',
#        '02893', '75287', '75013', '47374', '22180', '89502', '16365',
#        '04937', '02072', '02127', '02740', '02170', '43204', '48186',
#        '66614', '93001', '90303', '90260', '76006', '34203', '44110',
#        '11215', '92647', '91766', '90047', '90037', '45211', '33604',
#        '33147', '17013', '80226', '92806', '75201', '02144', '33708',
#        '11542', '13208', '61104', '02141', '75202', '92104', '30605',
#        '04901', '10543', '03820', '22312', '53212', '53216', '53218',
#        '48195', '10463', '11214', '10457', '97402', '94509', '60641',
#        '11216', '07111', '53209', '10473', '75703', '78550', '76133',
#        '33612', '10469', '11205', '44120', '11249', '12401', '08901',
#        '90266', '33135', '53208', '10465', '17522', '63139', '93305',
#        '01109', '53206', '01832', '46312', '01602', '02171', '45219',
#        '45205', '33305', '10016', '11201', '60618', '28277', '11212',
#        '90044', '11238', '90019', '11236', '11208', '60605', '90247',
#        '90016', '90018', '13601', '06790', '02130', '89030', '01930',
#        '02118', '32810', '02125', '98101', '80904', '06704', '14607',
#        '33150', '21204', '01905', '45405', '14613', '60614', '60617',
#        '20011', '90004', '01960', '44646', '01970', '19121', '06360',
#        '90029', '01604', '15212', '91104', '10038', '14217', '06451',
#        '14220', '33127', '20024', '14218', '11694', '11417', '11692',
#        '10005', '14212', '10023', '60629', '33160', '33139', '58103',
#        '60639', '60804', '53211', '10001', '91016', '01040', '11102',
#        '30329', '06708', '02116', '02119', '06320', '02140', '11421',
#        '11419', '14206', '22303', '10018'], dtype=object)

# %%
list(multi2.loc[multi2['zip']=='78212','zri'])
# Out:
# [nan,
#  nan,
#  848.0,
#  853.0,
#  862.0,
#  866.0,
#  871.0,
#  874.0,
#  870.0,
#  869.0,
#  866.0,
#  856.0,
#  851.0,
#  852.0,
#  851.0,
#  855.0,
#  865.0,
#  874.0,
#  878.0,
#  879.0,
#  879.0,
#  880.0,
#  883.0,
#  882.0,
#  886.0,
#  884.0,
#  878.0,
#  876.0,
#  879.0,
#  886.0,
#  893.0,
#  904.0,
#  908.0,
#  905.0,
#  901.0,
#  905.0,
#  913.0,
#  917.0,
#  919.0,
#  929.0,
#  936.0,
#  938.0,
#  939.0,
#  931.0,
#  932.0,
#  932.0,
#  930.0,
#  925.0,
#  924.0,
#  932.0,
#  934.0,
#  925.0,
#  924.0,
#  916.0,
#  905.0,
#  902.0,
#  896.0,
#  892.0,
#  896.0,
#  894.0,
#  909.0,
#  913.0,
#  914.0,
#  918.0,
#  921.0,
#  922.0,
#  nan,
#  970.0,
#  964.0,
#  943.0,
#  951.0,
#  942.0,
#  933.0]

# %%
multi2.loc[multi2['zip']=='78212','zri'].interpolate(method = 'ffill').interpolate(method = 'bfill')
# Out:
# 895      848.0
# 2197     848.0
# 3499     848.0
# 4801     853.0
# 6103     862.0
#          ...
# 89431    964.0
# 90733    943.0
# 92035    951.0
# 93337    942.0
# 94639    933.0
# Name: zri, Length: 73, dtype: float64

# %%
for item in missing_zri:
    temp = multi2.loc[multi2['zip']==item,'zri']
    multi2.loc[multi2['zip']==item,'zri'] = temp.interpolate(method = 'linear').interpolate(method = 'ffill').interpolate(method = 'bfill')

# %%
multi2['zri'].isnull().value_counts()
# Out:
# False    95046
# Name: zri, dtype: int64

# %%
multi2 = multi2[multi2['year-month']!='2020-01']

# %%
multi2.drop(columns = ['SizeRank'], inplace = True)

# %%
multi2['year-month'].value_counts()
# Out:
# 2014-09    1302
# 2014-02    1302
# 2017-09    1302
# 2016-03    1302
# 2016-04    1302
#            ...
# 2019-02    1302
# 2018-01    1302
# 2015-07    1302
# 2015-04    1302
# 2018-09    1302
# Name: year-month, Length: 72, dtype: int64

# %%
multi2 = multi2.sort_values(['zip', 'year-month'])

# %%
# multi2.to_csv('./../data/zri_multifamily_v2.csv', index = False)

# %%
multi2
# Out:
#          zip      City State        Metro                 CountyName  \
# 1074   01013  Chicopee    MA  Springfield             Hampden County
# 2376   01013  Chicopee    MA  Springfield             Hampden County
# 3678   01013  Chicopee    MA  Springfield             Hampden County
# 4980   01013  Chicopee    MA  Springfield             Hampden County
# 6282   01013  Chicopee    MA  Springfield             Hampden County
# ...      ...       ...   ...          ...                        ...
# 88204  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough
# 89506  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough
# 90808  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough
# 92110  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough
# 93412  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough
#
#       year-month     zri
# 1074     2014-01   928.0
# 2376     2014-02   931.0
# 3678     2014-03   934.0
# 4980     2014-04   929.0
# 6282     2014-05   929.0
# ...          ...     ...
# 88204    2019-08  1277.0
# 89506    2019-09  1271.0
# 90808    2019-10  1299.0
# 92110    2019-11  1261.5
# 93412    2019-12  1224.0
#
# [93744 rows x 7 columns]
