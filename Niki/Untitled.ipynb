# %%
import pandas as pd
import numpy as np

# %%
tax = pd.read_csv('../data/final_TAXES_by_zip.csv')

# %%
tax = tax[tax['year']>2012]

# %%
tax.isna().sum()
# Out:
# ZIPCODE               0
# year                  0
# state_local_perc    726
# month                 0
# dtype: int64

# %%
tax.isna()
# Out:
#          ZIPCODE   year  state_local_perc  month
# 12         False  False             False  False
# 13         False  False             False  False
# 14         False  False             False  False
# 15         False  False             False  False
# 16         False  False             False  False
# ...          ...    ...               ...    ...
# 1085731    False  False             False  False
# 1085732    False  False             False  False
# 1085733    False  False             False  False
# 1085734    False  False             False  False
# 1085735    False  False             False  False
#
# [928548 rows x 4 columns]

# %%
z = pd.read_csv('../data/zri_acs_bikeshare_merged.csv')

# %%
z['zip'].nunique()
# Out:
# 1301

# %%
tax['ZIPCODE'].nunique()
# Out:
# 13165

# %%
tax
# Out:
#          ZIPCODE  year  state_local_perc  month
# 12          1001  2013          0.220576      1
# 13          1001  2013          0.219956      2
# 14          1001  2013          0.219336      3
# 15          1001  2013          0.218715      4
# 16          1001  2013          0.218095      5
# ...          ...   ...               ...    ...
# 1085731    99901  2018          0.008740      8
# 1085732    99901  2018          0.008406      9
# 1085733    99901  2018          0.008072     10
# 1085734    99901  2018          0.007738     11
# 1085735    99901  2018          0.007404     12
#
# [928548 rows x 4 columns]

# %%
z
# Out:
#          zip      City State        Metro                 CountyName     zri  \
# 0       1013  Chicopee    MA  Springfield             Hampden County   928.0
# 1       1013  Chicopee    MA  Springfield             Hampden County   931.0
# 2       1013  Chicopee    MA  Springfield             Hampden County   934.0
# 3       1013  Chicopee    MA  Springfield             Hampden County   929.0
# 4       1013  Chicopee    MA  Springfield             Hampden County   929.0
# ...      ...       ...   ...          ...                        ...     ...
# 93667  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough  1277.0
# 93668  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough  1271.0
# 93669  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough  1299.0
# 93670  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough  1261.5
# 93671  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough  1224.0
#
# ...

# %%
pwd
# Out:
# '/Users/nikiagrawal/Desktop/markerr/zillow-price-index-pred/Niki'

# %%
gdp = pd.read_csv('../../../../Downloads/GDP_byZip.csv')

# %%
gdp[gdp['year'] > 2013]
# Out:
#         county    zip usps_zip_pref_city usps_zip_pref_state    GeoName_y  \
# 358560    1001  36067         PRATTVILLE                  AL  Autauga, AL
# 358561    1001  36067         PRATTVILLE                  AL  Autauga, AL
# 358562    1001  36067         PRATTVILLE                  AL  Autauga, AL
# 358563    1001  36067         PRATTVILLE                  AL  Autauga, AL
# 358564    1001  36067         PRATTVILLE                  AL  Autauga, AL
# ...        ...    ...                ...                 ...          ...
# 896395   56045  82701          NEWCASTLE                  WY   Weston, WY
# 896396   56045  82701          NEWCASTLE                  WY   Weston, WY
# 896397   56045  82701          NEWCASTLE                  WY   Weston, WY
# 896398   56045  82701          NEWCASTLE                  WY   Weston, WY
# 896399   56045  82701          NEWCASTLE                  WY   Weston, WY
#
#                                        Description_y  \
# ...

# %%
gdp['GeoName_y']
# Out:
# 0         Autauga, AL
# 1         Autauga, AL
# 2         Autauga, AL
# 3         Autauga, AL
# 4         Autauga, AL
#              ...
# 896395     Weston, WY
# 896396     Weston, WY
# 896397     Weston, WY
# 896398     Weston, WY
# 896399     Weston, WY
# Name: GeoName_y, Length: 896400, dtype: object

# %%
z['CountyName']
# Out:
# 0                   Hampden County
# 1                   Hampden County
# 2                   Hampden County
# 3                   Hampden County
# 4                   Hampden County
#                    ...
# 93667    Matanuska Susitna Borough
# 93668    Matanuska Susitna Borough
# 93669    Matanuska Susitna Borough
# 93670    Matanuska Susitna Borough
# 93671    Matanuska Susitna Borough
# Name: CountyName, Length: 93672, dtype: object
