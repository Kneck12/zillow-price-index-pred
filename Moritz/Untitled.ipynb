# %%
import pandas as pd

arima_results=pd.read_csv('./../data/arima_model_results.csv')
pd.set_option('display.max_rows', 5000)

arima_results.sort_values('RSME')
# Out:
#       Unnamed: 0    ZIP arima_params arima_seasonal        RSME  \
# 942          942  77056    (2, 0, 0)  (0, 0, 0, 12)    4.384909
# 1200        1200  93307    (1, 1, 0)  (0, 0, 0, 12)    4.477003
# 762          762  48235    (0, 1, 1)  (0, 0, 0, 12)    4.617770
# 791          791  55404    (1, 1, 0)  (0, 0, 0, 12)    5.606076
# 668          668  33413    (1, 1, 0)  (0, 0, 0, 12)    5.981006
# 1198        1198  93304    (2, 1, 1)  (0, 0, 0, 12)    6.215478
# 1034        1034  85016    (1, 1, 0)  (0, 0, 0, 12)    6.235436
# 1201        1201  93308    (1, 1, 0)  (0, 0, 0, 12)    6.422006
# 867          867  63116    (3, 1, 0)  (0, 0, 0, 12)    6.689594
# 570          570  29615    (2, 1, 0)  (0, 0, 0, 12)    6.787358
# 254          254  10472    (1, 1, 0)  (0, 0, 0, 12)    7.012379
# 731          731  44052    (2, 0, 0)  (0, 0, 0, 12)    7.016684
# 994          994  78758    (1, 1, 0)  (1, 0, 0, 12)    7.415545
# 901          901  75063    (1, 1, 0)  (0, 0, 0, 12)    7.829293
# ...

# %%
arima_results[arima_results['ZIP']<2000].sort_values('RSME', ascending=False)
# Out:
#     Unnamed: 0   ZIP arima_params arima_seasonal        RSME  \
# 20          20  1760    (1, 1, 0)  (0, 0, 1, 12)  139.642144
# 31          31  1854    (2, 1, 0)  (1, 0, 0, 12)  116.859427
# 36          36  1915    (1, 1, 2)  (1, 0, 0, 12)  107.982776
# 17          17  1702    (1, 1, 0)  (0, 0, 1, 12)  103.806343
# 28          28  1850    (1, 1, 0)  (0, 0, 0, 12)   86.241707
# 38          38  1960    (2, 1, 0)  (0, 0, 0, 12)   67.266364
# 32          32  1876    (5, 1, 0)  (0, 0, 0, 12)   66.301472
# 35          35  1905    (1, 1, 1)  (0, 0, 0, 12)   64.145048
# 24          24  1841    (3, 1, 0)  (2, 0, 0, 12)   63.341431
# 16          16  1610    (2, 1, 0)  (0, 0, 0, 12)   60.265019
# 27          27  1845    (2, 1, 1)  (0, 0, 0, 12)   58.918042
# 10          10  1545    (2, 1, 0)  (0, 0, 0, 12)   57.904607
# 8            8  1440    (2, 1, 1)  (0, 0, 1, 12)   57.431004
# 18          18  1752    (3, 1, 0)  (0, 0, 0, 12)   57.194254
# ...
