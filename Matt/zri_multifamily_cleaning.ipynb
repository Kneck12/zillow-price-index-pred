# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np

def time_series_gaps(df, ts_start_col):
    '''
    Returns a dictionary containing:
        keys: the row indices of any row with missing data
        values: numeric horizontal (column) start and end indices of any periods of missing data
    
    time series data must be running row-wise for the function to work
    
    ts_start_col is the numeric index of the column in the dataframe at which the time series begins
    the function assumes the time series runs from ts_start_col all the way to the right side of the dataframe
    '''
    gaps = {}
    for i in range(df.shape[0]):
        curr_gaps = []
        curr_ts = df.iloc[i,:]
        if curr_ts.isnull().any():
            j = ts_start_col
            while j < len(curr_ts):
                if pd.isnull(curr_ts[j]):
                    gap_start = int(j)
                    gap_end = None
                    k = int(j)
                    while gap_end is None:
                        if k == len(curr_ts) - 1:
                            if pd.isnull(curr_ts[k]):
                                gap_end = int(k)
                                curr_gaps.append((gap_start, gap_end))
                                j = int(k)+1
                            else:   
                                gap_end = int(k) - 1
                                curr_gaps.append((gap_start, gap_end))
                                j = int(k)+1
                        elif pd.isnull(curr_ts[k]):
                            k+=1
                        else:
                            gap_end = int(k) - 1
                            curr_gaps.append((gap_start, gap_end))
                            j = int(k)
                else:
                    j += 1
        if curr_gaps != []:
            gaps[i] = curr_gaps
    return gaps

def get_rejected_gaps(gaps, gap_limit):
    '''
    takes gaps dictionary generated by time_series_gaps, returns list of row indices that contain gaps >= gap_limit
    '''
    over_limit = []
    for key, val in gaps.items():
        if len(val) > 1:
            for i in range(len(val)):
                width = val[i][1] - val[i][0] + 1
                if width >= gap_limit:
                    over_limit.append(key)
        else:
            width = val[0][1] - val[0][0] + 1
            if width >= gap_limit:
                over_limit.append(key)
    return list(set(over_limit))

# %%
multi = pd.read_csv('./../data/Zip_Zri_MultiFamilyResidenceRental.csv')

# %%
type(multi['RegionName'][0])
# Out:
# numpy.int64

# %%
multi
# Out:
#       RegionID  RegionName            City State  \
# 0        61639       10025        New York    NY
# 1        84654       60657         Chicago    IL
# 2        61637       10023        New York    NY
# 3        91982       77494            Katy    TX
# 4        84616       60614         Chicago    IL
# ...        ...         ...             ...   ...
# 1856     90755       75202          Dallas    TX
# 1857     94610       84627         Ephraim    UT
# 1858     84452       60301        Oak Park    IL
# 1859     94629       84647  Mount Pleasant    UT
# 1860     91695       77046         Houston    TX
#
#                                  Metro       CountyName  SizeRank  2010-09  \
# 0          New York-Newark-Jersey City  New York County         1   2930.0
# 1             Chicago-Naperville-Elgin      Cook County         2   1447.0
# 2          New York-Newark-Jersey City  New York County         3   2797.0
# 3     Houston-The Woodlands-Sugar Land    Harris County         4      NaN
# 4             Chicago-Naperville-Elgin      Cook County         5   1437.0
# ...                                ...              ...       ...      ...
# 1856       Dallas-Fort Worth-Arlington    Dallas County      1857    997.0
# 1857                               NaN   Sanpete County      1858      NaN
# 1858          Chicago-Naperville-Elgin      Cook County      1859      NaN
# 1859                               NaN   Sanpete County      1860      NaN
# 1860  Houston-The Woodlands-Sugar Land    Harris County      1861      NaN
#
#       2010-10  2010-11  ...  2019-04  2019-05  2019-06  2019-07  2019-08  \
# 0      2952.0   2926.0  ...   3484.0   3523.0   3573.0   3622.0   3664.0
# 1      1465.0   1469.0  ...   1731.0   1749.0   1768.0   1787.0   1801.0
# 2      2811.0   2813.0  ...   3449.0   3459.0   3479.0   3491.0   3510.0
# 3         NaN      NaN  ...   1226.0   1250.0   1264.0   1251.0   1246.0
# 4      1469.0   1490.0  ...   1888.0   1911.0   1934.0   1950.0   1953.0
# ...       ...      ...  ...      ...      ...      ...      ...      ...
# 1856   1019.0   1042.0  ...   1615.0   1619.0   1628.0      NaN      NaN
# 1857      NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
# 1858      NaN      NaN  ...   1447.0   1483.0   1495.0   1511.0   1537.0
# 1859      NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
# 1860      NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
#
#       2019-09  2019-10  2019-11  2019-12  2020-01
# 0      3698.0   3704.0   3692.0   3715.0   3676.0
# 1      1806.0   1789.0   1761.0   1747.0   1731.0
# 2      3521.0   3574.0   3608.0   3561.0      NaN
# 3      1252.0   1280.0   1310.0   1294.0   1286.0
# 4      1952.0   1921.0   1958.0      NaN   1916.0
# ...       ...      ...      ...      ...      ...
# 1856   1729.0   1697.0   1739.0      NaN      NaN
# 1857      NaN      NaN      NaN   1298.0      NaN
# 1858   1570.0   1580.0   1625.0      NaN      NaN
# 1859      NaN      NaN      NaN      NaN   1221.0
# 1860      NaN      NaN      NaN      NaN      NaN
#
# [1861 rows x 120 columns]

# %%
multi['RegionName'] = multi['RegionName'].map(lambda x: str(x))

# %%
multi['RegionName'].map(lambda x: len(x)).value_counts()
# Out:
# 5    1621
# 4     240
# Name: RegionName, dtype: int64

# %%
multi['RegionName'] = multi['RegionName'].map(lambda x: '0'+x if len(x)<5 else x)

# %%
multi.rename(columns = {'RegionName':'zip'}, inplace = True)

# %%
multi = multi.iloc[:,1:] # drop RegionID column, just a unique identifier

# %%
multi
# Out:
#         zip            City State                             Metro  \
# 0     10025        New York    NY       New York-Newark-Jersey City
# 1     60657         Chicago    IL          Chicago-Naperville-Elgin
# 2     10023        New York    NY       New York-Newark-Jersey City
# 3     77494            Katy    TX  Houston-The Woodlands-Sugar Land
# 4     60614         Chicago    IL          Chicago-Naperville-Elgin
# ...     ...             ...   ...                               ...
# 1856  75202          Dallas    TX       Dallas-Fort Worth-Arlington
# 1857  84627         Ephraim    UT                               NaN
# 1858  60301        Oak Park    IL          Chicago-Naperville-Elgin
# 1859  84647  Mount Pleasant    UT                               NaN
# 1860  77046         Houston    TX  Houston-The Woodlands-Sugar Land
#
#            CountyName  SizeRank  2010-09  2010-10  2010-11  2010-12  ...  \
# 0     New York County         1   2930.0   2952.0   2926.0   2904.0  ...
# 1         Cook County         2   1447.0   1465.0   1469.0   1467.0  ...
# 2     New York County         3   2797.0   2811.0   2813.0   2784.0  ...
# 3       Harris County         4      NaN      NaN      NaN      NaN  ...
# 4         Cook County         5   1437.0   1469.0   1490.0   1503.0  ...
# ...               ...       ...      ...      ...      ...      ...  ...
# 1856    Dallas County      1857    997.0   1019.0   1042.0   1063.0  ...
# 1857   Sanpete County      1858      NaN      NaN      NaN      NaN  ...
# 1858      Cook County      1859      NaN      NaN      NaN      NaN  ...
# 1859   Sanpete County      1860      NaN      NaN      NaN      NaN  ...
# 1860    Harris County      1861      NaN      NaN      NaN      NaN  ...
#
#       2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  \
# 0      3484.0   3523.0   3573.0   3622.0   3664.0   3698.0   3704.0   3692.0
# 1      1731.0   1749.0   1768.0   1787.0   1801.0   1806.0   1789.0   1761.0
# 2      3449.0   3459.0   3479.0   3491.0   3510.0   3521.0   3574.0   3608.0
# 3      1226.0   1250.0   1264.0   1251.0   1246.0   1252.0   1280.0   1310.0
# 4      1888.0   1911.0   1934.0   1950.0   1953.0   1952.0   1921.0   1958.0
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1856   1615.0   1619.0   1628.0      NaN      NaN   1729.0   1697.0   1739.0
# 1857      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1858   1447.0   1483.0   1495.0   1511.0   1537.0   1570.0   1580.0   1625.0
# 1859      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1860      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#       2019-12  2020-01
# 0      3715.0   3676.0
# 1      1747.0   1731.0
# 2      3561.0      NaN
# 3      1294.0   1286.0
# 4         NaN   1916.0
# ...       ...      ...
# 1856      NaN      NaN
# 1857   1298.0      NaN
# 1858      NaN      NaN
# 1859      NaN   1221.0
# 1860      NaN      NaN
#
# [1861 rows x 119 columns]

# %%
multi = pd.concat([multi.iloc[:,0:6], multi.iloc[:,46:]], axis = 1)

# %%
multi
# Out:
#         zip            City State                             Metro  \
# 0     10025        New York    NY       New York-Newark-Jersey City
# 1     60657         Chicago    IL          Chicago-Naperville-Elgin
# 2     10023        New York    NY       New York-Newark-Jersey City
# 3     77494            Katy    TX  Houston-The Woodlands-Sugar Land
# 4     60614         Chicago    IL          Chicago-Naperville-Elgin
# ...     ...             ...   ...                               ...
# 1856  75202          Dallas    TX       Dallas-Fort Worth-Arlington
# 1857  84627         Ephraim    UT                               NaN
# 1858  60301        Oak Park    IL          Chicago-Naperville-Elgin
# 1859  84647  Mount Pleasant    UT                               NaN
# 1860  77046         Houston    TX  Houston-The Woodlands-Sugar Land
#
#            CountyName  SizeRank  2014-01  2014-02  2014-03  2014-04  ...  \
# 0     New York County         1   3333.0   3338.0   3340.0   3323.0  ...
# 1         Cook County         2   1647.0   1645.0   1635.0   1650.0  ...
# 2     New York County         3   3135.0   3138.0   3136.0   3131.0  ...
# 3       Harris County         4      NaN      NaN   1081.0   1093.0  ...
# 4         Cook County         5   1756.0   1759.0   1754.0   1774.0  ...
# ...               ...       ...      ...      ...      ...      ...  ...
# 1856    Dallas County      1857   1297.0   1284.0   1295.0   1297.0  ...
# 1857   Sanpete County      1858      NaN      NaN      NaN      NaN  ...
# 1858      Cook County      1859      NaN      NaN      NaN      NaN  ...
# 1859   Sanpete County      1860      NaN      NaN      NaN      NaN  ...
# 1860    Harris County      1861      NaN      NaN      NaN      NaN  ...
#
#       2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  \
# 0      3484.0   3523.0   3573.0   3622.0   3664.0   3698.0   3704.0   3692.0
# 1      1731.0   1749.0   1768.0   1787.0   1801.0   1806.0   1789.0   1761.0
# 2      3449.0   3459.0   3479.0   3491.0   3510.0   3521.0   3574.0   3608.0
# 3      1226.0   1250.0   1264.0   1251.0   1246.0   1252.0   1280.0   1310.0
# 4      1888.0   1911.0   1934.0   1950.0   1953.0   1952.0   1921.0   1958.0
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1856   1615.0   1619.0   1628.0      NaN      NaN   1729.0   1697.0   1739.0
# 1857      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1858   1447.0   1483.0   1495.0   1511.0   1537.0   1570.0   1580.0   1625.0
# 1859      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1860      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#       2019-12  2020-01
# 0      3715.0   3676.0
# 1      1747.0   1731.0
# 2      3561.0      NaN
# 3      1294.0   1286.0
# 4         NaN   1916.0
# ...       ...      ...
# 1856      NaN      NaN
# 1857   1298.0      NaN
# 1858      NaN      NaN
# 1859      NaN   1221.0
# 1860      NaN      NaN
#
# [1861 rows x 79 columns]

# %%
gaps = time_series_gaps(multi, 7)

# %%
rej_gaps = get_rejected_gaps(gaps, 6)

# %%
multi2 = multi.drop(rej_gaps, axis = 0)

# %%
multi2
# Out:
#         zip         City State                             Metro  \
# 0     10025     New York    NY       New York-Newark-Jersey City
# 1     60657      Chicago    IL          Chicago-Naperville-Elgin
# 2     10023     New York    NY       New York-Newark-Jersey City
# 3     77494         Katy    TX  Houston-The Woodlands-Sugar Land
# 4     60614      Chicago    IL          Chicago-Naperville-Elgin
# ...     ...          ...   ...                               ...
# 1849  04937    Fairfield    ME                               NaN
# 1850  60606      Chicago    IL          Chicago-Naperville-Elgin
# 1852  12307  Schenectady    NY           Albany-Schenectady-Troy
# 1855  18232     Lansford    PA        Allentown-Bethlehem-Easton
# 1856  75202       Dallas    TX       Dallas-Fort Worth-Arlington
#
#               CountyName  SizeRank  2014-01  2014-02  2014-03  2014-04  ...  \
# 0        New York County         1   3333.0   3338.0   3340.0   3323.0  ...
# 1            Cook County         2   1647.0   1645.0   1635.0   1650.0  ...
# 2        New York County         3   3135.0   3138.0   3136.0   3131.0  ...
# 3          Harris County         4      NaN      NaN   1081.0   1093.0  ...
# 4            Cook County         5   1756.0   1759.0   1754.0   1774.0  ...
# ...                  ...       ...      ...      ...      ...      ...  ...
# 1849     Somerset County      1850    794.0    793.0    790.0    792.0  ...
# 1850         Cook County      1851   2004.0   2001.0   2016.0   2041.0  ...
# 1852  Schenectady County      1853      NaN   1044.0      NaN   1028.0  ...
# 1855       Carbon County      1856    775.0    778.0    780.0    783.0  ...
# 1856       Dallas County      1857   1297.0   1284.0   1295.0   1297.0  ...
#
#       2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  \
# 0      3484.0   3523.0   3573.0   3622.0   3664.0   3698.0   3704.0   3692.0
# 1      1731.0   1749.0   1768.0   1787.0   1801.0   1806.0   1789.0   1761.0
# 2      3449.0   3459.0   3479.0   3491.0   3510.0   3521.0   3574.0   3608.0
# 3      1226.0   1250.0   1264.0   1251.0   1246.0   1252.0   1280.0   1310.0
# 4      1888.0   1911.0   1934.0   1950.0   1953.0   1952.0   1921.0   1958.0
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1849   1092.0   1111.0   1108.0   1105.0   1113.0   1113.0   1146.0      NaN
# 1850   2145.0   2155.0   2166.0   2183.0   2206.0   2228.0   2217.0   2230.0
# 1852    937.0    949.0    964.0    974.0    978.0    978.0      NaN      NaN
# 1855    781.0    773.0    769.0    762.0    758.0    758.0      NaN      NaN
# 1856   1615.0   1619.0   1628.0      NaN      NaN   1729.0   1697.0   1739.0
#
#       2019-12  2020-01
# 0      3715.0   3676.0
# 1      1747.0   1731.0
# 2      3561.0      NaN
# 3      1294.0   1286.0
# 4         NaN   1916.0
# ...       ...      ...
# 1849      NaN      NaN
# 1850   2200.0   2192.0
# 1852   1039.0   1047.0
# 1855      NaN      NaN
# 1856      NaN      NaN
#
# [1302 rows x 79 columns]

# %%
multi2 = pd.melt(multi2, id_vars = multi2.columns[0:6], value_vars = multi2.columns[7:], var_name = 'year-month', value_name = 'zri')

# %%
missing_zri = multi2[multi2['zri'].isnull()]['zip'].unique()

#        '02125', '33407', '44052', '01876', '98101', '99654', '80904',
#        '06704', '14607', '33150', '21204', '01905', '45405', '14613',
#        '60614', '10002', '60617', '20011', '90004', '01960', '44646',
#        '01970', '19121', '06360', '90029', '01604', '15212', '91104',
#        '10038', '14217', '33066', '06451', '14220', '33127', '20024',
#        '14218', '11694', '11417', '11692', '10005', '14212', '10023',
#        '60629', '33160', '33139', '75056', '60634', '58103', '60639',
#        '60630', '60804', '85719', '53211', '10001', '91016', '01040',
#        '11102', '60607', '30329', '06489', '06708', '02116', '02119',
#        '06320', '02140', '11421', '11419', '14206', '22303', '10018',
#        '91105'], dtype=object)

# %%
list(multi2.loc[multi2['zip']=='78212','zri'])
# Out:
# [nan,
#  848.0,
#  853.0,
#  862.0,
#  866.0,
#  871.0,
#  874.0,
#  870.0,
#  869.0,
#  866.0,
#  856.0,
#  851.0,
#  852.0,
#  851.0,
#  855.0,
#  865.0,
#  874.0,
#  878.0,
#  879.0,
#  879.0,
#  880.0,
#  883.0,
#  882.0,
#  886.0,
#  884.0,
#  878.0,
#  876.0,
#  879.0,
#  886.0,
#  893.0,
#  904.0,
#  908.0,
#  905.0,
#  901.0,
#  905.0,
#  913.0,
#  917.0,
#  919.0,
#  929.0,
#  936.0,
#  938.0,
#  939.0,
#  931.0,
#  932.0,
#  932.0,
#  930.0,
#  925.0,
#  924.0,
#  932.0,
#  934.0,
#  925.0,
#  924.0,
#  916.0,
#  905.0,
#  902.0,
#  896.0,
#  892.0,
#  896.0,
#  894.0,
#  909.0,
#  913.0,
#  914.0,
#  918.0,
#  921.0,
#  922.0,
#  nan,
#  970.0,
#  964.0,
#  943.0,
#  951.0,
#  942.0,
#  933.0]

# %%
multi2.loc[multi2['zip']=='78212','zri'].interpolate(method = 'ffill').interpolate(method = 'bfill')
# Out:
# 895      848.0
# 2197     848.0
# 3499     853.0
# 4801     862.0
# 6103     866.0
#          ...
# 88129    964.0
# 89431    943.0
# 90733    951.0
# 92035    942.0
# 93337    933.0
# Name: zri, Length: 72, dtype: float64

# %%
for item in missing_zri:
    temp = multi2.loc[multi2['zip']==item,'zri']
    multi2.loc[multi2['zip']==item,'zri'] = temp.interpolate(method = 'linear').interpolate(method = 'ffill').interpolate(method = 'bfill')

# %%
multi2['zri'].isnull().value_counts()
# Out:
# False    93744
# Name: zri, dtype: int64

# %%
multi2 = multi2[multi2['year-month']!='2020-01']

# %%
multi2.drop(columns = ['SizeRank'], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16136/2017855625.py in <module>
# ----> 1 multi2.drop(columns = ['SizeRank'], inplace = True)
#
# ~\anaconda3\envs\env1\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\env1\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4899                 weight  1.0     0.8
#    4900         """
# -> 4901         return super().drop(
#    4902             labels=labels,
#    4903             axis=axis,
#
# ~\anaconda3\envs\env1\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\envs\env1\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\envs\env1\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6016         if mask.any():
#    6017             if errors != "ignore":
# -> 6018                 raise KeyError(f"{labels[mask]} not found in axis")
#    6019             indexer = indexer[~mask]
#    6020         return self.delete(indexer)
#
# KeyError: "['SizeRank'] not found in axis"

# %%
multi2 = multi2.sort_values(['zip', 'year-month'])

# %%
multi2.to_csv('./../data/zri_multifamily_v2.csv', index = False)
