# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from datetime import datetime
import pmdarima as pm
from pmdarima.utils import diff
from sklearn.metrics import mean_squared_error
from pmdarima.metrics import smape
import pickle
import sklearn

# %% [markdown]
# # Importing and preparing zri and acs data for merging

# %%
zri = pd.read_csv('./../data/zri_multifamily_v2.csv')

# %%
zri['zip'] = zri['zip'].map(lambda x: str(x))

# %%
zri['zip'].map(lambda x: len(x)).value_counts()
# Out:
# 5    79272
# 4    14472
# Name: zip, dtype: int64

# %%
zri['zip'] = zri['zip'].map(lambda x: '0' + x if len(x)<5 else x)

# %%
zri['zip'].map(lambda x: len(x)).value_counts()
# Out:
# 5    93744
# Name: zip, dtype: int64

# %%
zri['year']=zri['year-month'].map(lambda x: int(x[0:4]))

# %%
zri['month']=zri['year-month'].map(lambda x: int(x[5:]))

# %%
years = range(2014,2020)

# %%
months = range(1, 13)

# %%
datetime_col = [datetime(year=i, month=j, day=1) for i in years for j in months]

# %%
datetime_col = datetime_col*1302

# %%
zri['datetime'] = datetime_col

# %%
zri.drop(columns = 'year-month', inplace = True)

# %%
zri
# Out:
#          zip      City State        Metro                 CountyName     zri  \
# 0      01013  Chicopee    MA  Springfield             Hampden County   928.0
# 1      01013  Chicopee    MA  Springfield             Hampden County   931.0
# 2      01013  Chicopee    MA  Springfield             Hampden County   934.0
# 3      01013  Chicopee    MA  Springfield             Hampden County   929.0
# 4      01013  Chicopee    MA  Springfield             Hampden County   929.0
# ...      ...       ...   ...          ...                        ...     ...
# 93739  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough  1277.0
# 93740  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough  1271.0
# 93741  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough  1299.0
# 93742  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough  1261.5
# 93743  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough  1224.0
#
#        year  month   datetime
# 0      2014      1 2014-01-01
# 1      2014      2 2014-02-01
# 2      2014      3 2014-03-01
# 3      2014      4 2014-04-01
# 4      2014      5 2014-05-01
# ...     ...    ...        ...
# 93739  2019      8 2019-08-01
# 93740  2019      9 2019-09-01
# 93741  2019     10 2019-10-01
# 93742  2019     11 2019-11-01
# 93743  2019     12 2019-12-01
#
# [93744 rows x 9 columns]

# %%
acs = pd.read_csv('./../data/acs_engineered_features.csv')

# %%
acs['zip'] = acs['zip'].map(lambda x: str(x))

# %%
acs['zip'].map(lambda x: len(x)).value_counts()
# Out:
# 5    83482
# 4     9170
# Name: zip, dtype: int64

# %%
acs['zip'] = acs['zip'].map(lambda x: '0' + x if len(x)<5 else x)

# %%
acs['zip'].map(lambda x: len(x)).value_counts()
# Out:
# 5    92652
# Name: zip, dtype: int64

# %%
acs.drop(columns = 'census_period', axis = 1, inplace = True)

# %%
acs
# Out:
#          zip  year_usable  percent_white  percent_black  percent_asian  \
# 0      01013         2013       0.729579       0.020723       0.013756
# 1      01013         2014       0.714417       0.023463       0.013473
# 2      01013         2015       0.720119       0.027857       0.016777
# 3      01013         2016       0.713799       0.017445       0.016638
# 4      01013         2017       0.703894       0.022238       0.018442
# ...      ...          ...            ...            ...            ...
# 92647  99901         2015       0.653872       0.002271       0.063146
# 92648  99901         2016       0.654374       0.004016       0.061487
# 92649  99901         2017       0.649705       0.004228       0.073631
# 92650  99901         2018       0.645762       0.004947       0.076319
# 92651  99901         2019       0.644756       0.005447       0.077426
#
#        percent_hispanic  percent_native_am  percent_other_race  percent_0_17  \
# 0              0.218793           0.000000            0.005002      0.230494
# 1              0.231235           0.000000            0.004491      0.224682
# 2              0.217971           0.001357            0.005065      0.217248
# 3              0.237499           0.000538            0.002197      0.221131
# 4              0.241627           0.001116            0.001652      0.222336
# ...                 ...                ...                 ...           ...
# 92647          0.044026           0.142407            0.002710      0.233756
# 92648          0.046444           0.143932            0.000000      0.232584
# 92649          0.048334           0.135379            0.001604      0.230079
# 92650          0.046126           0.129138            0.005384      0.225609
# 92651          0.047574           0.135096            0.004213      0.222836
#
#        percent_18_39  ...  median_building_age  income_per_capita  \
# 0           0.311375  ...                 62.0            20433.0
# 1           0.312437  ...                 62.0            20940.0
# 2           0.335730  ...                 66.0            20889.0
# 3           0.328625  ...                 72.0            21371.0
# 4           0.338573  ...                 73.0            21477.0
# ...              ...  ...                  ...                ...
# 92647       0.279833  ...                 38.0            31563.0
# 92648       0.279977  ...                 38.0            31487.0
# 92649       0.285121  ...                 40.0            32010.0
# 92650       0.284103  ...                 40.0            32671.0
# 92651       0.285445  ...                 41.0            33755.0
#
#        poverty_rate  total_pop  percent_workforce_unemployed  \
# 0          0.190522      22391                      0.104113
# 1          0.201543      21822                      0.104320
# 2          0.173591      22113                      0.113411
# 3          0.155696      22299                      0.115569
# 4          0.169816      22394                      0.114075
# ...             ...        ...                           ...
# 92647      0.101846      13651                      0.086316
# 92648      0.114447      13694                      0.085095
# 92649      0.121194      13717                      0.078951
# 92650      0.108124      13745                      0.075428
# 92651      0.106987      13768                      0.069999
#
#        percent_work_from_home  median_age  percent_female  gini_index  \
# 0                    0.008853        36.4        0.510250      0.4210
# 1                    0.014770        36.6        0.501650      0.4179
# 2                    0.012946        35.5        0.506851      0.4110
# 3                    0.013701        35.8        0.512669      0.4061
# 4                    0.020243        34.9        0.514200      0.4117
# ...                       ...         ...             ...         ...
# 92647                0.021073        38.7        0.478353      0.3981
# 92648                0.022509        38.8        0.481233      0.4057
# 92649                0.023050        38.7        0.485602      0.4110
# 92650                0.026582        39.2        0.485922      0.4158
# 92651                0.024453        39.5        0.485401      0.4157
#
#        percent_not_us_citizen
# 0                    0.055960
# 1                    0.057190
# 2                    0.056483
# 3                    0.050182
# 4                    0.050013
# ...                       ...
# 92647                0.025493
# 92648                0.023952
# 92649                0.025953
# 92650                0.035504
# 92651                0.033338
#
# [92652 rows x 37 columns]

# %%
zri.drop(columns = ['City', 'State', 'Metro', 'CountyName'], inplace = True)

# %%
merged = pd.merge(zri, acs, left_on = ['zip','year'], right_on = ['zip','year_usable'], how = 'left')

# %%
null_check = {}
for col in merged.columns:
    if merged[col].isnull().any():
        null_check[col] = merged[col].isnull().sum()
null_check
# Out:
# {'year_usable': 72,
#  'percent_white': 72,
#  'percent_black': 72,
#  'percent_asian': 72,
#  'percent_hispanic': 72,
#  'percent_native_am': 72,
#  'percent_other_race': 72,
#  'percent_0_17': 72,
#  'percent_18_39': 72,
#  'percent_40_64': 72,
#  'percent_65+': 72,
#  'percent_rental_units_vacant': 72,
#  'percent_rental_units_occupied': 72,
#  'percent_graduate_deg': 72,
#  'percent_bachelors': 72,
#  'percent_associates': 72,
#  'percent_highschool': 72,
#  'percent_less_highschool': 72,
#  'percent_commute_public_transport': 72,
#  'percent_commute_less_30': 72,
#  'percent_commute_30_to_59': 72,
#  'percent_commute_60_to_89': 72,
#  'percent_commute_90_more': 72,
#  'percent_new_city': 72,
#  'percent_new_unit': 72,
#  'percent_units_owner_occupied': 72,
#  'median_building_age': 72,
#  'income_per_capita': 72,
#  'poverty_rate': 72,
#  'total_pop': 72,
#  'percent_workforce_unemployed': 72,
#  'percent_work_from_home': 72,
#  'median_age': 72,
#  'percent_female': 72,
#  'gini_index': 72,
#  'percent_not_us_citizen': 72}

# %%
merged= merged[merged['zip']!= '11249']

# %%
null_check = {}
for col in merged.columns:
    if merged[col].isnull().any():
        null_check[col] = merged[col].isnull().sum()
null_check
# Out:
# {}

# %%
merged['zip'].nunique()
# Out:
# 1301

# %%
df = merged.drop(columns = ['year_usable'])

# %% [markdown]
# # Using CPI rent index to adjust for the value of the dollar across the timeframe

# %%
inf = pd.read_csv('./rent_inflation_cpi.csv')
inf.rename(columns = {'DATE':'Date', 'CUUR0000SEHA':'cpi_rent'},inplace=True)
inf['year'] = inf['Date'].map(lambda x: int(x[0:4]))
inf['month'] = inf['Date'].map(lambda x: int(x[5:7]))
inf = inf.loc[:, ['year', 'month', 'cpi_rent']]

# %%
inf
# Out:
#     year  month  cpi_rent
# 0   2014      1   272.317
# 1   2014      2   272.733
# 2   2014      3   273.486
# 3   2014      4   274.100
# 4   2014      5   274.710
# ..   ...    ...       ...
# 68  2019      9   333.834
# 69  2019     10   334.680
# 70  2019     11   335.819
# 71  2019     12   336.789
# 72  2020      1   337.825
#
# [73 rows x 3 columns]

# %%
# dxy = pd.read_csv('./DX-Y.NYB.csv')
# dxy['year'] = dxy['Date'].map(lambda x: int(x[0:4]))
# dxy['month'] = dxy['Date'].map(lambda x: int(x[5:7]))
# dxy = dxy.loc[:, ['year', 'month', 'Adj Close']]
# dxy.rename(columns = {'Adj Close' : 'pct_jan_2020_usd'}, inplace = True)
# dxy['pct_jan_2020_usd'] = dxy['pct_jan_2020_usd'].interpolate(method='linear')
# dxy = dxy.groupby(['year', 'month']).agg(pct_jan_2020_usd = ('pct_jan_2020_usd', 'mean'))
# dxy = dxy.reset_index(drop=False)
# dxy['pct_jan_2020_usd'] = dxy['pct_jan_2020_usd'].map(lambda x: x/float(dxy[dxy['year']==2020]['pct_jan_2020_usd']))
# dxy = dxy[dxy['year']!=2020]
# dxy

# %%
df
# Out:
#          zip     zri  year  month   datetime  percent_white  percent_black  \
# 0      01013   928.0  2014      1 2014-01-01       0.714417       0.023463
# 1      01013   931.0  2014      2 2014-02-01       0.714417       0.023463
# 2      01013   934.0  2014      3 2014-03-01       0.714417       0.023463
# 3      01013   929.0  2014      4 2014-04-01       0.714417       0.023463
# 4      01013   929.0  2014      5 2014-05-01       0.714417       0.023463
# ...      ...     ...   ...    ...        ...            ...            ...
# 93739  99654  1277.0  2019      8 2019-08-01       0.794726       0.008443
# 93740  99654  1271.0  2019      9 2019-09-01       0.794726       0.008443
# 93741  99654  1299.0  2019     10 2019-10-01       0.794726       0.008443
# 93742  99654  1261.5  2019     11 2019-11-01       0.794726       0.008443
# 93743  99654  1224.0  2019     12 2019-12-01       0.794726       0.008443
#
#        percent_asian  percent_hispanic  percent_native_am  ...  \
# 0           0.013473          0.231235           0.000000  ...
# 1           0.013473          0.231235           0.000000  ...
# 2           0.013473          0.231235           0.000000  ...
# 3           0.013473          0.231235           0.000000  ...
# 4           0.013473          0.231235           0.000000  ...
# ...              ...               ...                ...  ...
# 93739       0.014660          0.050576           0.049059  ...
# 93740       0.014660          0.050576           0.049059  ...
# 93741       0.014660          0.050576           0.049059  ...
# 93742       0.014660          0.050576           0.049059  ...
# 93743       0.014660          0.050576           0.049059  ...
#
#        median_building_age  income_per_capita  poverty_rate  total_pop  \
# 0                     62.0            20940.0      0.201543    21822.0
# 1                     62.0            20940.0      0.201543    21822.0
# 2                     62.0            20940.0      0.201543    21822.0
# 3                     62.0            20940.0      0.201543    21822.0
# 4                     62.0            20940.0      0.201543    21822.0
# ...                    ...                ...           ...        ...
# 93739                 23.0            30300.0      0.095106    60641.0
# 93740                 23.0            30300.0      0.095106    60641.0
# 93741                 23.0            30300.0      0.095106    60641.0
# 93742                 23.0            30300.0      0.095106    60641.0
# 93743                 23.0            30300.0      0.095106    60641.0
#
#        percent_workforce_unemployed  percent_work_from_home  median_age  \
# 0                          0.104320                0.014770        36.6
# 1                          0.104320                0.014770        36.6
# 2                          0.104320                0.014770        36.6
# 3                          0.104320                0.014770        36.6
# 4                          0.104320                0.014770        36.6
# ...                             ...                     ...         ...
# 93739                      0.102037                0.050081        33.6
# 93740                      0.102037                0.050081        33.6
# 93741                      0.102037                0.050081        33.6
# 93742                      0.102037                0.050081        33.6
# 93743                      0.102037                0.050081        33.6
#
#        percent_female  gini_index  percent_not_us_citizen
# 0            0.501650      0.4179                0.057190
# 1            0.501650      0.4179                0.057190
# 2            0.501650      0.4179                0.057190
# 3            0.501650      0.4179                0.057190
# 4            0.501650      0.4179                0.057190
# ...               ...         ...                     ...
# 93739        0.476311      0.4004                0.018997
# 93740        0.476311      0.4004                0.018997
# 93741        0.476311      0.4004                0.018997
# 93742        0.476311      0.4004                0.018997
# 93743        0.476311      0.4004                0.018997
#
# [93672 rows x 40 columns]

# %%
df = pd.merge(df, inf, on = ['year', 'month'], how = 'left')

# %%
df['zri_adj'] = df['zri']/df['cpi_rent']*100

# %%
df.drop(columns = 'cpi_rent', inplace = True)

# %%
df = df.set_index('datetime')

# %%
df
# Out:
#               zip     zri  year  month  percent_white  percent_black  \
# datetime
# 2014-01-01  01013   928.0  2014      1       0.714417       0.023463
# 2014-02-01  01013   931.0  2014      2       0.714417       0.023463
# 2014-03-01  01013   934.0  2014      3       0.714417       0.023463
# 2014-04-01  01013   929.0  2014      4       0.714417       0.023463
# 2014-05-01  01013   929.0  2014      5       0.714417       0.023463
# ...           ...     ...   ...    ...            ...            ...
# 2019-08-01  99654  1277.0  2019      8       0.794726       0.008443
# 2019-09-01  99654  1271.0  2019      9       0.794726       0.008443
# 2019-10-01  99654  1299.0  2019     10       0.794726       0.008443
# 2019-11-01  99654  1261.5  2019     11       0.794726       0.008443
# 2019-12-01  99654  1224.0  2019     12       0.794726       0.008443
#
#             percent_asian  percent_hispanic  percent_native_am  \
# datetime
# 2014-01-01       0.013473          0.231235           0.000000
# 2014-02-01       0.013473          0.231235           0.000000
# 2014-03-01       0.013473          0.231235           0.000000
# 2014-04-01       0.013473          0.231235           0.000000
# 2014-05-01       0.013473          0.231235           0.000000
# ...                   ...               ...                ...
# 2019-08-01       0.014660          0.050576           0.049059
# 2019-09-01       0.014660          0.050576           0.049059
# 2019-10-01       0.014660          0.050576           0.049059
# 2019-11-01       0.014660          0.050576           0.049059
# 2019-12-01       0.014660          0.050576           0.049059
#
#             percent_other_race  ...  income_per_capita  poverty_rate  \
# datetime                        ...
# 2014-01-01            0.004491  ...            20940.0      0.201543
# 2014-02-01            0.004491  ...            20940.0      0.201543
# 2014-03-01            0.004491  ...            20940.0      0.201543
# 2014-04-01            0.004491  ...            20940.0      0.201543
# 2014-05-01            0.004491  ...            20940.0      0.201543
# ...                        ...  ...                ...           ...
# 2019-08-01            0.003051  ...            30300.0      0.095106
# 2019-09-01            0.003051  ...            30300.0      0.095106
# 2019-10-01            0.003051  ...            30300.0      0.095106
# 2019-11-01            0.003051  ...            30300.0      0.095106
# 2019-12-01            0.003051  ...            30300.0      0.095106
#
#             total_pop  percent_workforce_unemployed  percent_work_from_home  \
# datetime
# 2014-01-01    21822.0                      0.104320                0.014770
# 2014-02-01    21822.0                      0.104320                0.014770
# 2014-03-01    21822.0                      0.104320                0.014770
# 2014-04-01    21822.0                      0.104320                0.014770
# 2014-05-01    21822.0                      0.104320                0.014770
# ...               ...                           ...                     ...
# 2019-08-01    60641.0                      0.102037                0.050081
# 2019-09-01    60641.0                      0.102037                0.050081
# 2019-10-01    60641.0                      0.102037                0.050081
# 2019-11-01    60641.0                      0.102037                0.050081
# 2019-12-01    60641.0                      0.102037                0.050081
#
#             median_age  percent_female  gini_index  percent_not_us_citizen  \
# datetime
# 2014-01-01        36.6        0.501650      0.4179                0.057190
# 2014-02-01        36.6        0.501650      0.4179                0.057190
# 2014-03-01        36.6        0.501650      0.4179                0.057190
# 2014-04-01        36.6        0.501650      0.4179                0.057190
# 2014-05-01        36.6        0.501650      0.4179                0.057190
# ...                ...             ...         ...                     ...
# 2019-08-01        33.6        0.476311      0.4004                0.018997
# 2019-09-01        33.6        0.476311      0.4004                0.018997
# 2019-10-01        33.6        0.476311      0.4004                0.018997
# 2019-11-01        33.6        0.476311      0.4004                0.018997
# 2019-12-01        33.6        0.476311      0.4004                0.018997
#
#                zri_adj
# datetime
# 2014-01-01  340.779312
# 2014-02-01  341.359498
# 2014-03-01  341.516568
# 2014-04-01  338.927399
# 2014-05-01  338.174803
# ...                ...
# 2019-08-01  383.900817
# 2019-09-01  380.728146
# 2019-10-01  388.131947
# 2019-11-01  375.648787
# 2019-12-01  363.432297
#
# [93672 rows x 40 columns]

# %% [markdown]
# # Train-test splitting and modeling

# %%
arima = pm.arima.auto_arima

# %%
def forecast(number_steps, model):
    pred = []
    conf = []
    
    for i in range(number_steps):
        fc, conf_int = model.predict(n_periods=1, return_conf_int=True)
        fc = fc.tolist()[0]
        conf_int = np.asarray(conf_int).tolist()[0]
        pred.append(fc)
        conf.append(conf_int)

        # Updates the existing model with the prediction it just made
        model.update(fc)
    return pred, conf

# %%
zips = list(df['zip'].unique())

test = df[df['year']>=2019].drop(columns = ['year', 'month'])
train = df[df['year']<2019].drop(columns = ['year', 'month'])

y_train = train[['zip','zri', 'zri_adj']]
y_test = test[['zip','zri', 'zri_adj']]

x_train = train.drop(columns = ['zri', 'zri_adj'])
x_test = test.drop(columns = ['zri', 'zri_adj'])

# %%
order_dict = {}
rmse_dict = {}
resid_dict = {}
pred_dict = {}
conf_int_dict = {}

# %%
start = datetime.now()
for item in zips:
    curr_train = y_train[y_train['zip']==item]
    curr_test = y_test[y_test['zip']==item]
    
    curr_model = arima(curr_train['zri'], start_p=0, start_q=0, m=12)
    order_dict[item] = (curr_model.order, curr_model.seasonal_order)
    
    pred_dict[item], conf_int_dict[item] = forecast(curr_test.shape[0], curr_model)
    resid_dict[item] = pred_dict[item] - curr_test['zri']
    
    rmse_dict[item] = np.sqrt(sum(resid_dict[item]**2)/len(resid_dict[item]))
elapsed = datetime.now()-start
print(elapsed)
# Out:
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(0,0,0)[12]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(3,1,1)(0,0,1)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1373, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(3,1,2)(1,0,1)[12]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 268, in fun_and_grad
#     self._update_grad()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 238, in _update_grad
#     self._update_grad_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 155, in update_grad
#     self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_numdiff.py", line 486, in approx_derivative
#     return _dense_difference(fun_wrapped, x0, f0, h,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_numdiff.py", line 557, in _dense_difference
#     df = fun(x) - f0
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_numdiff.py", line 437, in fun_wrapped
#     f = np.atleast_1d(fun(x, *args, **kwargs))
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1373, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(1,0,0)(1,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(0,0,1)(1,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(1,0,1)(1,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,1)(1,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(3,0,0)(1,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1284, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: Schur decomposition solver error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(1,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(0,0,0)[12]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(1,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,1)(1,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
# ...
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(0,0,0)[12]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(0,0,0)[12]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(3,1,1)(0,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 268, in fun_and_grad
#     self._update_grad()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 238, in _update_grad
#     self._update_grad_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 155, in update_grad
#     self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_numdiff.py", line 486, in approx_derivative
#     return _dense_difference(fun_wrapped, x0, f0, h,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_numdiff.py", line 557, in _dense_difference
#     df = fun(x) - f0
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_numdiff.py", line 437, in fun_wrapped
#     f = np.atleast_1d(fun(x, *args, **kwargs))
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1373, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# 0:58:13.027645

# %% [markdown]
# # Seeing whether modeling on deflated or normal zri data gives better accuracy

# %%
order_dict_adj = {}
rmse_dict_adj = {}
resid_dict_adj = {}
pred_dict_adj = {}
conf_int_dict_adj = {}

# %%
start = datetime.now()
for item in zips:
    curr_train = y_train[y_train['zip']==item]
    curr_test = y_test[y_test['zip']==item]
    
    curr_model = arima(curr_train['zri_adj'], start_p=0, start_q=0, m=12)
    order_dict_adj[item] = (curr_model.order, curr_model.seasonal_order)
    
    pred_dict_adj[item], conf_int_dict_adj[item] = forecast(curr_test.shape[0], curr_model)
    resid_dict_adj[item] = pred_dict_adj[item] - curr_test['zri_adj']
    
    rmse_dict_adj[item] = np.sqrt(sum(resid_dict_adj[item]**2)/len(resid_dict_adj[item]))
elapsed = datetime.now()-start
print(elapsed)
# Out:
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,2)(1,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(1,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1284, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: Schur decomposition solver error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(1,1,0)(1,0,1)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1373, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(0,0,0)[12]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(0,0,1)[12]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(1,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(3,0,0)(1,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(0,0,0)[12]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(0,0,0)[12]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,1)(1,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,2)(1,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(0,0,0)[12]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# ...
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(1,0,0)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1284, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: Schur decomposition solver error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(0,0,0)[12]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,0)(0,0,0)[12]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\pmdarima\arima\arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 267, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 233, in _update_fun
#     self._update_fun_impl()
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\base\model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# 1:02:25.637029

# %%
fig = go.Figure()
fig.add_trace(go.Line(x = curr_train.index, y = curr_train['zri_adj'], mode = 'lines'))
fig.add_trace(go.Line(x = curr_test.index, y = curr_test['zri_adj'], mode = 'lines'))
fig.add_trace(go.Line(x = curr_test.index, y = pred_dict_adj[curr_train['zip'][0]], mode = 'lines'))
# fig.add_trace(go.Line(x = curr_test.index, y = np.asarray(conf)[:,0], mode = 'lines'))
# fig.add_trace(go.Line(x = curr_test.index, y = np.asarray(conf)[:,1], mode = 'lines', fill = 'tonexty'))
# Out:
# C:\Users\fayma\anaconda3\envs\env1\lib\site-packages\plotly\graph_objs\_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <div>                            <div id="a026e70f-345f-4908-9848-020a6b07f454" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a026e70f-345f-4908-9848-020a6b07f454")) {                    Plotly.newPlot(                        "a026e70f-345f-4908-9848-020a6b07f454",                        [{"mode":"lines","type":"scatter","x":["2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01T00:00:00","2015-06-01T00:00:00","2015-07-01T00:00:00","2015-08-01T00:00:00","2015-09-01T00:00:00","2015-10-01T00:00:00","2015-11-01T00:00:00","2015-12-01T00:00:00","2016-01-01T00:00:00","2016-02-01T00:00:00","2016-03-01T00:00:00","2016-04-01T00:00:00","2016-05-01T00:00:00","2016-06-01T00:00:00","2016-07-01T00:00:00","2016-08-01T00:00:00","2016-09-01T00:00:00","2016-10-01T00:00:00","2016-11-01T00:00:00","2016-12-01T00:00:00","2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00"],"y":[437.7251512024589,437.057488459409,442.43581024257185,443.63371032469894,439.0084088675331,436.2180872508817,443.44212446786946,440.35690566255664,437.77293361822746,442.31768733086005,443.7336455771215,441.4790973888647,445.0016336851675,449.73423185747316,442.5528908981739,439.0016854843828,438.706045840736,432.2336868621308,426.7887727638156,417.67107444925944,412.0621839295748,412.537833243501,416.4341662016657,420.6672985261191,423.624333913234,429.6785608159111,438.85801512152074,447.69269992351485,453.50397917542267,459.27367844759414,461.15703592915224,448.44855596879654,434.1688910296292,420.7723035952064,409.8319887793572,409.92947627462956,416.51975338339923,425.69137868124426,431.99023839825765,435.7120175987063,439.32514956965065,439.6155072661838,438.39012502717634,434.27825474426373,427.37246509469236,424.71773766376356,420.57120926216135,414.7764921759519,412.023329987166,413.60454457508797,415.6602286289544,418.29380325353657,420.485684588491,419.07777756834366,417.0959226681614,416.9642383775507,415.8204601082937,413.7892557372578,412.3864085341762,412.8503917614642]},{"mode":"lines","type":"scatter","x":["2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00"],"y":[408.17329397998145,404.7789036957141,402.42677389905134,397.65363060502983,393.52266550877073,391.35273765454497,389.3186170292969,383.90081710448,380.72814632422103,388.1319469343851,375.6487869953755,363.43229737313277]},{"mode":"lines","type":"scatter","x":["2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00"],"y":[413.6294090604076,414.0172658436355,414.52261574459993,415.1728908850422,415.7151783950745,415.3644412410079,414.87105719199286,414.8383060895776,414.5509687872252 ...

# %%
resid_df_adj = pd.DataFrame(resid_dict_adj).reset_index(drop=True)

# %%
for col in resid_df_adj.columns:
    resid_df_adj[col] = resid_df_adj[col] / 100 * inf.loc[60:71, 'cpi_rent'].reset_index(drop=True)

# %%
resid_df_adj = resid_df_adj.T

# %%
resid_df = pd.DataFrame(resid_dict).reset_index(drop=True)

# %%
for col in resid_df.columns:
    resid_df[col] = resid_df[col] / inf.loc[60:71, 'cpi_rent'].reset_index(drop=True) * 100

# %%
resid_df = resid_df.T

# %%
np.mean(list(rmse_dict.values())) # RMSE from inflated model residuals
# Out:
# 50.1395887293849

# %%
np.mean(np.sqrt((resid_df_adj**2).sum(axis = 1)/12)) # RMSE from deflated model residuals, converted back to inflated
# Out:
# 52.34616016658373

# %%
np.mean(np.sqrt((resid_df**2).sum(axis = 1)/12)) # RMSE from inflated model residuals, converted to deflated
# Out:
# 15.065473493598674

# %%
np.mean(list(rmse_dict_adj.values())) # RMSE from deflated model residuals
# Out:
# 15.726478778012323

# %%
# resid_df.to_csv('./../data/sarima_residuals.csv', index = True)

# %% [markdown]
# Using normal, non-deflated data yielded higher-performing sarimas
# # Random forest for feat imp on sarima residuals
