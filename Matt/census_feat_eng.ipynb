# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./../data/acs_5yr_merged_v3.csv')

# %%
df
# Out:
#          zip   do_date  nonfamily_households  family_households  \
# 0       1013  20072011                  3553               5549
# 1       1013  20082012                  3688               5217
# 2       1013  20092013                  3713               5297
# 3       1013  20102014                  3615               5516
# 4       1013  20112015                  3784               5412
# ...      ...       ...                   ...                ...
# 92647  99901  20092013                  1952               3343
# 92648  99901  20102014                  2094               3211
# 92649  99901  20112015                  2010               3257
# 92650  99901  20122016                  1919               3290
# 92651  99901  20132017                  1860               3410
#
#        median_year_structure_built  rent_burden_not_computed  \
# 0                           1949.0                     217.0
# 1                           1950.0                     251.0
# ...

# %%
df['zip'] = df['zip'].map(lambda x: str(x))

# %%
df['zip'] = df['zip'].map(lambda x: '0'+x if len(x) < 5 else x)

# %%
df['zip'].map(lambda x: len(x)).value_counts()
# Out:
# 5    92652
# Name: zip, dtype: int64

# %%
df
# Out:
#          zip   do_date  nonfamily_households  family_households  \
# 0      01013  20072011                  3553               5549
# 1      01013  20082012                  3688               5217
# 2      01013  20092013                  3713               5297
# 3      01013  20102014                  3615               5516
# 4      01013  20112015                  3784               5412
# ...      ...       ...                   ...                ...
# 92647  99901  20092013                  1952               3343
# 92648  99901  20102014                  2094               3211
# 92649  99901  20112015                  2010               3257
# 92650  99901  20122016                  1919               3290
# 92651  99901  20132017                  1860               3410
#
#        median_year_structure_built  rent_burden_not_computed  \
# 0                           1949.0                     217.0
# 1                           1950.0                     251.0
# ...

# %%
df.rename(columns = {'year':'year_usable'}, inplace = True)

# %%
df['year_usable'][0]
# Out:
# numpy.int64

# %%
df['year_usable'] = df['year_usable'] + 2

# %%
(df['poverty']/df['total_pop'])
# Out:
# 0        0.185655
# 1        0.196270
# 2        0.168724
# 3        0.151262
# 4        0.164955
#            ...
# 92647    0.099846
# 92648    0.112458
# 92649    0.119560
# 92650    0.106511
# 92651    0.105317
# Length: 92652, dtype: float64

# %%
(df['poverty']/df['pop_determined_poverty_status'])
# Out:
# 0.257831020790369

# %%
df['pop_determined_poverty_status']
# Out:
# 0        21819.0
# 1        21251.0
# 2        21493.0
# 3        21664.0
# 4        21753.0
#           ...
# 92647    13383.0
# 92648    13456.0
# 92649    13532.0
# 92650    13540.0
# 92651    13553.0
# Name: pop_determined_poverty_status, Length: 92652, dtype: float64

# %%
# engineer average commute length
# mode of commute
# income per capita
# poverty rate

# %%
zri = pd.read_csv('./../data/zri_multifamily_v2.csv')

# %%
zri
# Out:
#          zip      City State        Metro                 CountyName  \
# 0       1013  Chicopee    MA  Springfield             Hampden County
# 1       1013  Chicopee    MA  Springfield             Hampden County
# 2       1013  Chicopee    MA  Springfield             Hampden County
# 3       1013  Chicopee    MA  Springfield             Hampden County
# 4       1013  Chicopee    MA  Springfield             Hampden County
# ...      ...       ...   ...          ...                        ...
# 92437  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough
# 92438  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough
# 92439  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough
# 92440  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough
# 92441  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough
#
#       year-month     zri
# 0        2014-02   931.0
# 1        2014-03   934.0
# 2        2014-04   929.0
# 3        2014-05   929.0
# ...

# %%
zri['zip'] = zri['zip'].map(lambda x: str(x))

# %%
zri['zip'] = zri['zip'].map(lambda x: '0'+x if len(x)<5 else x)

# %%
zri['zip'].map(lambda x: len(x)).value_counts()
# Out:
# 5    92442
# Name: zip, dtype: int64

# %%
zri['year'] = zri['year-month'].map(lambda x: int(x[0:4]))

# %%
merged = pd.merge(zri, df, left_on = ['zip', 'year'], right_on = ['zip', 'year_usable'], how = 'left')

# %%
merged = merged.sort_values(['zip', 'year-month'])

# %%
merged
# Out:
#          zip      City State        Metro                 CountyName  \
# 0      01013  Chicopee    MA  Springfield             Hampden County
# 1      01013  Chicopee    MA  Springfield             Hampden County
# 2      01013  Chicopee    MA  Springfield             Hampden County
# 3      01013  Chicopee    MA  Springfield             Hampden County
# 4      01013  Chicopee    MA  Springfield             Hampden County
# ...      ...       ...   ...          ...                        ...
# 92437  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough
# 92438  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough
# 92439  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough
# 92440  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough
# 92441  99654   Wasilla    AK    Anchorage  Matanuska Susitna Borough
#
#       year-month     zri  year     do_date  nonfamily_households  ...  \
# ...

# %%
merged.to_csv()
